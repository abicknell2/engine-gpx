# %% [markdown]
# # Test Multi-Class Implementation

# %%
from gpkit import Model, Variable

# %% [markdown]
# ### Some testing of model and variable inhertiance

# %%
class TestA(Model):
    def setup(self, extra=None):
        self.a = a = Variable('a', 5)
        self.b = b = Variable('b', 6)
        self.c = c = Variable('c')
        
        self.constr = self.get_constraints()        
        return self.constr
    
    def get_constraints(self):
        return [self.c >= self.a + self.b]

# %%
class TestB(Model):
    def setup(self, testa):
        testa.substitutions[testa.a] = 10  # try using substitutions --> Doesn't Work
        return testa  # need to return entire object in order to get the substitutions

# %%
class TestC(Model):
    def setup(self, testl):
        constr = []
        constr.extend(testl)  # this seems to work just returning the object as part of the subs
        return constr

# %%
testa = TestA()

# %%
testb = TestB(testa)

# %%
m = TestC(testb)

# %%
m.cost = testa.c

# %%
print(m.solve().table())
# Out:
# Using solver 'cvxopt'
# Solving for 1 variables.
# Solving took 0.00679 seconds.
#
# Cost
# ----
#  16
#
# Free Variables
# --------------
# c : 16
#
# Constants
# ---------
# a : 10
# b : 6
#
# Sensitivities
# -------------
# a : +0.63
# b : +0.38
#
# Tightest Constraints
# --------------------
#     +1 : c >= a + b

# %% [markdown]
# ## `MCell` Testing

# %%
from gpkit import units

# %%
from gpx.multiclass.mccell import MCell

# %%
from gpx.manufacturing import Process, QNACell

# %%
import numpy as np

# %%
cells = [QNACell(process=Process(), qnaconstr=False), 
         QNACell(process=Process(),qnaconstr=False)]

# %%
m = MCell(cells=cells)

# %%
# add the cells to the constraints
# m.extend(cells)

# %%
# add constraints to both cells to loop variations
m.extend([c.c2a >= c.c2d for c in cells])

# %%
# substitutions for cell rates
# where do these need to be integrated? at the MClass?
subs_to_update = {
    cells[0].lam : 10,
    cells[1].lam : 5,
    # cell cv (since not in processes)
    cells[0].c2s : 0.5,
    cells[1].c2s : 0.5,
    # process times
    cells[0].process.t : 10,
    cells[1].process.t : 5,
}

# %%
# add all cells substitutions
for c in cells:
    m.substitutions.update(c.substitutions)

# %%
m.substitutions.update(subs_to_update)

# %%
# m.substitutions[m.m] = 2

# %%
# cost function
# normally, WIP in the line is calculated at the fabline object
m.cost = np.sum([c.lam*c.W*units('count') for c in cells]) + m.m

# %%
sol = m.solve()
print(sol.table())
# Out:
# Using solver 'cvxopt'
# Solving for 17 variables.
# Solving took 0.101 seconds.
#
# Cost
# ----
#  5.927 [count]
#
# Free Variables
# --------------
#               | MCell
#     \bar{W_q} : 3.028  [min]      queueing time
#  \bar{\alpha} : 0.325             1-rho
# \bar{\lambda} : 15     [count/hr] aggregate production rate
#    \bar{\rho} : 0.675             utilization
#   \bar{c^2_a} : 0.54              Arrival coefficient of variation squared
#   \bar{c^2_d} : 0.54              Departure coefficient of variation
#   \bar{c^2_s} : 0.54              Service coefficient of variation
#     \bar{t_s} : 8.333  [min]      service time
#             m : 3.086  [count]    workstation count
#
#               | QNACell6
#             W : 13.03  [min]      Total flow time through cell
#            Wq : 3.028  [min]      Expected queueing time
#           c2a : 0.54              Arrival coefficient of variation squared
#           c2d : 0.54              Departure coefficient of variation squared
#
#               | QNACell7
#             W : 8.028  [min]      Total flow time through cell
#            Wq : 3.028  [min]      Expected queueing time
#           c2a : 0.54              Arrival coefficient of variation squared
#           c2d : 0.54              Departure coefficient of variation squared
#
# Constants
# ---------
#         | MCell
#     x_0 : 0.6667             arrival rate mixture parameter
#     x_1 : 0.3333             arrival rate mixture parameter
#
#         | Process3
#       t : 10      [min]      process time
#
#         | Process4
#       t : 5       [min]      process time
#
#         | QNACell6
# \lambda : 10      [count/hr] Production rate
#     c2s : 0.5                Process coefficient of variation squared
#
#         | QNACell7
# \lambda : 5       [count/hr] Production rate
#     c2s : 0.5                Process coefficient of variation squared
#
# Sensitivities
# -------------
#         | Process3
#       t : +0.72   process time
#
#         | Process4
#       t : +0.15   process time
#
#         | QNACell6
# \lambda : +0.85   Production rate
#     c2s : +0.11   Process coefficient of variation squared
#
#         | QNACell7
# \lambda : +0.43   Production rate
#     c2s : +0.014  Process coefficient of variation squared
#
# Tightest Constraints
# --------------------
#        | MCell
#  +0.39 : \bar{\lambda} = \bar{\rho}*m/\bar{t_s}
#  +0.39 : \bar{\lambda} >= QNACell6.\lambda + QNACell7.\lambda
#  +0.37 : QNACell6.W >= QNACell6.Wq + Process3.t
#   +0.3 : \bar{\alpha} + \bar{\rho} <= 1
#  +0.27 : \bar{t_s} >= x_0*Process3.t + x_1*Process4.t

# %% [markdown]
# ## `MClass` Testing

# %%
from gpx.manufacturing import QNACell, Process, FabLine

# %%
from gpx.multiclass import MCSystem, MClass

# %%
import numpy as np

# %%
p1 = Process()
prod1 = MClass(
    line=FabLine([QNACell(process=p1) for _ in range(3)], return_cells=False),
    rate=10
)

# %%
p2 = Process()
prod2 = MClass(
    line=FabLine([QNACell(process=p2) for _ in range(3)], return_cells=False),
    rate=5
)

# %%
classes = [prod1, prod2]

# %%
# cellmap = [[p.cells[i] for p in classes] for i in range(3)]  # share all cells
cellmap = [[p.cells[i] for p in classes] for i in range(2)]  # share all but last cells

# %%
system = MCSystem(
    classes=classes,
    cellmap=cellmap
)

# %%
# this should be showing the other substitutions for cell rate and line rate
classes[0].substitutions
# Out:
# {QNACell.\lambda: 10,
#  QNACell1.\lambda: 10,
#  QNACell2.\lambda: 10,
#  FabLine.\lambda: 10,
#  MClass.\lambda: 10}

# %%
# subsitutions are not appearing in the system subsitutions
# but returns class substitutions

# system.substitutions[cellmap[0][0].lam]

# %%
# cost the WIP and the number of cells
system.cost = np.sum([c.line.L for c in classes])*0.1 + \
              np.sum([c.m for c in system.mcells]) + \
              np.sum([c.m for c in system.single_cells])

# %%
# substitute process times, cv
system.substitutions.update({
    prod1.cells[0].process.t : 5,
    prod1.cells[0].process.stdev : 5,
    prod2.cells[0].process.t : 10,
    prod2.cells[0].process.stdev : 5,
})

# %%
sol = system.solve()
print(sol.table())
# Out:
# Using solver 'cvxopt'
# Solving for 62 variables.
# Solving took 0.504 seconds.
#
# Cost
# ----
#  7.452 [count]
#
# Free Variables
# --------------
#               | FabLine
#             L : 8.079   [count]    Total WIP count
#             W : 0.8079  [hr]       Total flow time
#
#               | FabLine1
#             L : 5.87    [count]    Total WIP count
#             W : 1.174   [hr]       Total flow time
#
#               | MCSystem.MCell
#     \bar{W_q} : 11.14   [min]      queueing time
#  \bar{\alpha} : 0.1601             1-rho
# \bar{\lambda} : 15      [count/hr] aggregate production rate
#    \bar{\rho} : 0.8399             utilization
#   \bar{c^2_a} : 0.7008             Arrival coefficient of variation squared
#   \bar{c^2_d} : 0.5846             Departure coefficient of variation
#   \bar{c^2_s} : 0.5625             Service coefficient of variation
#     \bar{t_s} : 6.667   [min]      service time
#             m : 1.984   [count]    workstation count
#
#               | MCSystem.MCell1
#     \bar{W_q} : 10.6    [min]      queueing time
#  \bar{\alpha} : 0.1547             1-rho
# \bar{\lambda} : 15      [count/hr] aggregate production rate
#    \bar{\rho} : 0.8453             utilization
#   \bar{c^2_a} : 0.5846             Arrival coefficient of variation squared
#   \bar{c^2_d} : 0.5659             Departure coefficient of variation
#   \bar{c^2_s} : 0.5625             Service coefficient of variation
#     \bar{t_s} : 6.667   [min]      service time
#             m : 1.972   [count]    workstation count
#
#               | Process1
#            cv : 1                  Coefficient of Variation
#
#               | Process2
#            cv : 0.5                Coefficient of Variation
#
#               | QNACell
#             W : 16.14   [min]      Total flow time through cell
#            Wq : 11.14   [min]      Expected queueing time
#           c2a : 0.8982             Arrival coefficient of variation squared
#           c2d : 0.5846             Departure coefficient of variation squared
#           c2s : 1                  Process coefficient of variation squared
#
#               | QNACell1
#             W : 15.6    [min]      Total flow time through cell
#            Wq : 10.6    [min]      Expected queueing time
#           c2a : 0.5846             Arrival coefficient of variation squared
#           c2d : 0.5659             Departure coefficient of variation squared
#           c2s : 1                  Process coefficient of variation squared
#
#               | QNACell2
#             W : 16.74   [min]      Total flow time through cell
#            Wq : 11.74   [min]      Expected queueing time
#        \alpha : 0.2345             (1-rho)
#           c2a : 0.5659             Arrival coefficient of variation squared
#           c2d : 0.8982             Departure coefficient of variation squared
#           c2s : 1                  Process coefficient of variation squared
#             m : 1.089   [count]    Number of parallel workstations
#           rho : 0.7655             Cell utilization
#      t_{\eta} : 5       [min]      Average cycle time including efficiency
#
#               | QNACell3
#             W : 21.14   [min]      Total flow time through cell
#            Wq : 11.14   [min]      Expected queueing time
#           c2a : 0.306              Arrival coefficient of variation squared
#           c2d : 0.5846             Departure coefficient of variation squared
#           c2s : 0.25               Process coefficient of variation squared
#
#               | QNACell4
#             W : 20.6    [min]      Total flow time through cell
#            Wq : 10.6    [min]      Expected queueing time
#           c2a : 0.5846             Arrival coefficient of variation squared
#           c2d : 0.5659             Departure coefficient of variation squared
#           c2s : 0.25               Process coefficient of variation squared
#
#               | QNACell5
#             W : 28.71   [min]      Total flow time through cell
#            Wq : 18.71   [min]      Expected queueing time
#        \alpha : 0.1772             (1-rho)
#           c2a : 0.5659             Arrival coefficient of variation squared
#           c2d : 0.306              Departure coefficient of variation squared
#           c2s : 0.25               Process coefficient of variation squared
#             m : 1.013   [count]    Number of parallel workstations
#           rho : 0.8228             Cell utilization
#      t_{\eta} : 10      [min]      Average cycle time including efficiency
#
# Constants
# ---------
#           | FabLine
#   \lambda : 10      [count/hr] Line Continuous Production Rate
#
#           | FabLine1
#   \lambda : 5       [count/hr] Line Continuous Production Rate
#
#           | MCSystem.MCell
#       x_0 : 0.6667             arrival rate mixture parameter
#       x_1 : 0.3333             arrival rate mixture parameter
#
#           | MCSystem.MCell1
#       x_0 : 0.6667             arrival rate mixture parameter
#       x_1 : 0.3333             arrival rate mixture parameter
#
#           | MClass
#   \lambda : 10      [count/hr] class production rate
#
#           | MClass1
#   \lambda : 5       [count/hr] class production rate
#
#           | Process1
#    \sigma : 5       [min]      standard deviation of process time
#         t : 5       [min]      process time
#
#           | Process2
#    \sigma : 5       [min]      standard deviation of process time
#         t : 10      [min]      process time
#
#           | QNACell
#   \lambda : 10      [count/hr] Production rate
#
#           | QNACell1
#   \lambda : 10      [count/hr] Production rate
#
#           | QNACell2
# \chi_{cv} : 1                  margin sensitivity to process variation
#    \eta_t : 1                  process time efficiency
#   \lambda : 10      [count/hr] Production rate
#
#           | QNACell3
#   \lambda : 5       [count/hr] Production rate
#
#           | QNACell4
#   \lambda : 5       [count/hr] Production rate
#
#           | QNACell5
# \chi_{cv} : 1                  margin sensitivity to process variation
#    \eta_t : 1                  process time efficiency
#   \lambda : 5       [count/hr] Production rate
#
# Sensitivities
# -------------
#           | FabLine
#   \lambda : +0.11   Line Continuous Production Rate
#
#           | FabLine1
#   \lambda : +0.079  Line Continuous Production Rate
#
#           | Process1
#         t : +0.3    process time
#    \sigma : +0.17   standard deviation of process time
#
#           | Process2
#         t : +0.34   process time
#    \sigma : +0.069  standard deviation of process time
#
#           | QNACell
#   \lambda : +0.12   Production rate
#
#           | QNACell1
#   \lambda : +0.12   Production rate
#
#           | QNACell2
#    \eta_t : +0.16   process time efficiency
#   \lambda : +0.12   Production rate
# \chi_{cv} : +0.07   margin sensitivity to process variation
#
#           | QNACell3
#   \lambda : +0.1    Production rate
#
#           | QNACell4
#   \lambda : +0.11   Production rate
#
#           | QNACell5
#    \eta_t : +0.15   process time efficiency
#   \lambda : +0.11   Production rate
# \chi_{cv} : +0.018  margin sensitivity to process variation
#
# Tightest Constraints
# --------------------
#        | MCSystem.MCell
#  +0.23 : .\bar{\lambda} = .\bar{\rho}*.m/.\bar{t_s}
#  +0.23 : .\bar{\lambda} >= QNACell.\lambda + QNACell3.\lambda
#  +0.21 : .\bar{\alpha} + .\bar{\rho} <= 1
#
#        | MCSystem.MCell1
#  +0.23 : .\bar{\lambda} = .\bar{\rho}*.m/.\bar{t_s}
#  +0.23 : .\bar{\lambda} >= QNACell1.\lambda + QNACell4.\lambda
