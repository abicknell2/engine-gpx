# %% [markdown]
# # 48-redundant-constraints-in-multiproduct
# Run models to see what the missing constraint is for a single product

# %%
from gpkit import Model, Variable, units
from gpx.multiclass import MClass, MCSystem
from gpx.manufacturing import QNACell, Process, FabLine

# %%
import numpy as np

# %% [markdown]
# ## Create a simple production system with a single product

# %%
processes = [Process() for i in range(2)]

# %%
processes[0] is processes[1]
# Out:
# False

# %%
cells = [QNACell(p) for p in processes]

# %%
line = FabLine(cells=cells)

# %%
## Update the substitutions
line.substitutions.update({
    # Process Times
    processes[0].t : 15*units('min'),
    processes[1].t : 30*units('min'),
})

# %%
### Process CV
line.substitutions.update({
    p.cv : 0.5 for p in processes
})

# %%
# Extend the process constraints
line.extend(processes)

# %% [markdown]
# Solving fails when extending the model with `processes` more than once

# %%
# Constrain the rate
line.substitutions[line.lam] = 50*units('count/hr')

# Set the cost
line.cost = np.sum([c.m for c in cells]) + line.L

# %%
print(line)
# Out:
# FabLine
# =======
#
# Cost
# ----
#  QNACell.m + QNACell1.m + L
#
# Constraints
# -----------
#   L = FabLine.\lambda·FabLine.W
#   QNACell1.c2a >= QNACell.c2d
#   QNACell1.c2d <= QNACell.c2a
#   FabLine.\lambda = QNACell.\lambda
#   FabLine.\lambda = QNACell1.\lambda
#   FabLine.W >= QNACell.W + QNACell1.W
#
#   QNACell
#    QNACell.Wq >= QNACell.rho/QNACell.\alpha·(QNACell.c2a + QNACell.c2s)/2·QNACell.t_{\eta}/QNACell.m
#    QNACell.c2d >= QNACell.\alpha·QNACell.c2a + QNACell.rho·QNACell.c2s
#    QNACell.\alpha + QNACell.rho <= 1
#    QNACell.\lambda <= QNACell.rho·QNACell.m/QNACell.t_{\eta}
#    QNACell.c2s >= Process1.cv²·QNACell.\chi_{cv}²
#    QNACell.W >= QNACell.Wq + QNACell.t_{\eta}
#    QNACell.t_{\eta} >= Process1.t·QNACell.\eta_t
#
#   QNACell1
#    QNACell1.Wq >= QNACell1.rho/QNACell1.\alpha·(QNACell1.c2a + QNACell1.c2s)/2·QNACell1.t_{\eta}/QNACell1.m
#    QNACell1.c2d >= QNACell1.\alpha·QNACell1.c2a + QNACell1.rho·QNACell1.c2s
#    QNACell1.\alpha + QNACell1.rho <= 1
#    QNACell1.\lambda <= QNACell1.rho·QNACell1.m/QNACell1.t_{\eta}
#    QNACell1.c2s >= Process2.cv²·QNACell1.\chi_{cv}²
#    QNACell1.W >= QNACell1.Wq + QNACell1.t_{\eta}
#    QNACell1.t_{\eta} >= Process2.t·QNACell1.\eta_t
#
#   Process1
#    Process1.cv = \sigma/Process1.t
#
#   Process2
#    Process2.cv = \sigma/Process2.t

# %%
print(line.solve(solver='cvxopt').table())
# Out:
# Using solver 'cvxopt'
#  for 24 free variables
#   in 28 posynomial inequalities.
# Solving took 0.17 seconds.
#
# Optimal Cost
# ------------
#  83.09
#
# Free Variables
# --------------
#          | FabLine
#        L : 41.35    [count]    Total WIP count
#        W : 0.8269   [hr]       Total flow time
#
#          | Process1
#   \sigma : 7.5      [min]      standard deviation of process time
#
#          | Process2
#   \sigma : 15       [min]      standard deviation of process time
#
#          | QNACell
#        W : 16.87    [min]      Total flow time through cell
#       Wq : 1.874    [min]      Expected queueing time
#   \alpha : 0.1231              (1-rho)
#  \lambda : 50       [count/hr] Production rate
#      c2a : 0.25                Arrival coefficient of variation squared
#      c2d : 0.25                Departure coefficient of variation squared
#      c2s : 0.25                Process coefficient of variation squared
#        m : 14.25    [count]    Number of parallel workstations
#      rho : 0.8769              Cell utilization
# t_{\eta} : 15       [min]      Average cycle time including efficiency
#
#          | QNACell1
#        W : 32.74    [min]      Total flow time through cell
#       Wq : 2.74     [min]      Expected queueing time
#   \alpha : 0.09057             (1-rho)
#  \lambda : 50       [count/hr] Production rate
#      c2a : 0.25                Arrival coefficient of variation squared
#      c2d : 0.25                Departure coefficient of variation squared
#      c2s : 0.25                Process coefficient of variation squared
#        m : 27.49    [count]    Number of parallel workstations
#      rho : 0.9094              Cell utilization
# t_{\eta} : 30       [min]      Average cycle time including efficiency
#
# Fixed Variables
# ---------------
#           | FabLine
#   \lambda : 50   [count/hr] Line Continuous Production Rate
#
#           | Process1
#        cv : 0.5             Coefficient of Variation
#         t : 15   [min]      process time
#
#           | Process2
#        cv : 0.5             Coefficient of Variation
#         t : 30   [min]      process time
#
#           | QNACell
# \chi_{cv} : 1               margin sensitivity to process variation
#    \eta_t : 1               process time efficiency
#
#           | QNACell1
# \chi_{cv} : 1               margin sensitivity to process variation
#    \eta_t : 1               process time efficiency
#
# Variable Sensitivities
# ----------------------
#           | FabLine
#   \lambda : +0.95   Line Continuous Production Rate
#
#           | Process1
#         t : +0.32   process time
#        cv : +0.045  Coefficient of Variation
#
#           | Process2
#         t : +0.63   process time
#        cv : +0.048  Coefficient of Variation
#
#           | QNACell
#    \eta_t : +0.32   process time efficiency
# \chi_{cv} : +0.045  margin sensitivity to process variation
#
#           | QNACell1
#    \eta_t : +0.63   process time efficiency
# \chi_{cv} : +0.048  margin sensitivity to process variation
#
# Most Sensitive Constraints
# --------------------------
#        | QNACell1
#  +0.63 : .t_{\eta} >= Process2.t·.\eta_t
#  +0.33 : .W >= .Wq + .t_{\eta}
#
#        | FabLine
#   +0.5 : .W >= QNACell.W + QNACell1.W
#   +0.3 : .\lambda = QNACell1.\lambda
#
#        | QNACell
#  +0.32 : .t_{\eta} >= Process1.t·.\eta_t

# %% [markdown]
# ## Smallest model to fail by adding multiple constraints

# %%
x = Variable('x')
y = Variable('y')

# %%
const = [x >= y]

# %%
m = Model(x, const)

# %%
m.substitutions[y] = 5

# %%
m.solve()
# Out:
# Using solver 'cvxopt'
#  for 1 free variables
#   in 2 posynomial inequalities.
# Solving took 0.00918 seconds.
# {'cost': 4.999999919599561,
#  'freevariables': {x: 4.999999919579763},
#  'constants': {y: 5},
#  'variables': {x: 4.999999919579763, y: 5},
#  'sensitivities': {'constraints': {gpkit.PosynomialInequality(x >= y): 1.0000000000000004},
#   'cost': {x: 1.0},
#   'variables': {x: -4.440892098500626e-16, y: 1.0000000000000004},
#   'constants': {x: -4.440892098500626e-16, y: 1.0000000000000004}},
#  'soltime': 0.009181976318359375}

# %%
## Now add the constraint again
m.extend(const)

# %%
m
# Out:
# <gpkit.Model object containing 2 top-level constraint(s) and 2 variable(s)>

# %%
m.solve()
# Out:
# Using solver 'cvxopt'
#  for 1 free variables
#   in 3 posynomial inequalities.
# Solving took 0.0509 seconds.
# {'cost': 5.000003701674993,
#  'freevariables': {x: 5.0000036754435495},
#  'constants': {y: 5},
#  'variables': {x: 5.0000036754435495, y: 5},
#  'sensitivities': {'constraints': {gpkit.PosynomialInequality(x >= y): 0.5000000023887884},
#   'cost': {x: 1.0},
#   'variables': {x: -4.777576667613914e-09, y: 1.0000000047775766},
#   'constants': {x: -4.777576667613914e-09, y: 1.0000000047775766}},
#  'soltime': 0.05092120170593262}

# %% [markdown]
# This does not seem to encounter the same issue when multiple constraints are added as constraints and not as `Model` types

# %% [markdown]
# ### Adding the multiple constraint as a constraints not as `Model`

# %% [markdown]
# ## Production System model with added process constraints

# %%
line2 = FabLine(cells=cells)

# %%
# Substitute times and variation
line2.substitutions.update({
    processes[0].t  : 15*units('min'),
    processes[0].cv : 0.5,
    processes[1].t  : 60*units('min'),
    processes[1].cv : 0.5,
    # rate
    line2.lam : 30*units('count/hr')
})

## Add cost
line2.cost = np.sum([c.m for c in cells]) + line2.L

# %%
line2.extend([p.cv == p.stdev/p.t for p in processes])

# %%
line2
# Out:
# <gpkit.FabLine object containing 10 top-level constraint(s) and 33 variable(s)>

# %%
line2.solve()
# Out:
# Using solver 'cvxopt'
#  for 24 free variables
#   in 28 posynomial inequalities.
# Solving took 0.0757 seconds.
# {'cost': 82.77512169795602,
#  'freevariables': {QNACell.m: 8.853216361431732,
#   QNACell1.m: 32.729075581679325,
#   FabLine4.L: 41.19282984571403,
#   FabLine4.W: 1.3730943281907306,
#   QNACell.c2d: 0.24999999755930044,
#   QNACell1.c2a: 0.2499999991564233,
#   QNACell1.c2d: 0.25000008648606964,
#   QNACell.c2a: 0.2500001702538519,
#   QNACell.\lambda: 29.99999999999426,
#   QNACell1.\lambda: 29.99999999999426,
#   QNACell.W: 17.34760119306645,
#   QNACell1.W: 65.03805854132982,
#   QNACell.rho: 0.8471497528203272,
#   QNACell.\alpha: 0.15285024197842514,
#   QNACell.t_{\eta}: 15.000000026826601,
#   QNACell.Wq: 2.3476012381727718,
#   QNACell.c2s: 0.2500000000133219,
#   QNACell1.rho: 0.9166161728453469,
#   QNACell1.\alpha: 0.083383827510009,
#   QNACell1.t_{\eta}: 60.00000000023803,
#   QNACell1.Wq: 5.0380585476734705,
#   QNACell1.c2s: 0.25000000407099116,
#   Process1.\sigma: 7.49999999999915,
#   Process2.\sigma: 29.99999999999426},
#  'constants': {FabLine4.\lambda: 30,
#   QNACell.\chi_{cv}: 1,
#   QNACell.\eta_t: 1,
#   Process1.cv: 0.5,
#   Process1.t: 15,
#   QNACell1.\eta_t: 1,
#   QNACell1.\chi_{cv}: 1,
#   Process2.cv: 0.5,
#   Process2.t: 60},
#  'variables': {QNACell.m: 8.853216361431732,
#   QNACell1.m: 32.729075581679325,
#   FabLine4.L: 41.19282984571403,
#   FabLine4.W: 1.3730943281907306,
#   QNACell.c2d: 0.24999999755930044,
#   QNACell1.c2a: 0.2499999991564233,
#   QNACell1.c2d: 0.25000008648606964,
#   QNACell.c2a: 0.2500001702538519,
#   QNACell.\lambda: 29.99999999999426,
#   QNACell1.\lambda: 29.99999999999426,
#   QNACell.W: 17.34760119306645,
#   QNACell1.W: 65.03805854132982,
#   QNACell.rho: 0.8471497528203272,
#   QNACell.\alpha: 0.15285024197842514,
#   QNACell.t_{\eta}: 15.000000026826601,
#   QNACell.Wq: 2.3476012381727718,
#   QNACell.c2s: 0.2500000000133219,
#   QNACell1.rho: 0.9166161728453469,
#   QNACell1.\alpha: 0.083383827510009,
#   QNACell1.t_{\eta}: 60.00000000023803,
#   QNACell1.Wq: 5.0380585476734705,
#   QNACell1.c2s: 0.25000000407099116,
#   Process1.\sigma: 7.49999999999915,
#   Process2.\sigma: 29.99999999999426,
#   FabLine4.\lambda: 30,
#   QNACell.\chi_{cv}: 1,
#   QNACell.\eta_t: 1,
#   Process1.cv: 0.5,
#   Process1.t: 15,
#   QNACell1.\eta_t: 1,
#   QNACell1.\chi_{cv}: 1,
#   Process2.cv: 0.5,
#   Process2.t: 60},
#  'sensitivities': {'constraints': {gpkit.MonomialEquality(FabLine4.L = FabLine4.\lambda·FabLine4.W): -0.49764746939654386,
#    gpkit.PosynomialInequality(QNACell1.c2a >= QNACell.c2d): 0.01601138624217009,
#    gpkit.PosynomialInequality(QNACell1.c2d <= QNACell.c2a): 0.009537644230184238,
#    gpkit.MonomialEquality(FabLine4.\lambda = QNACell.\lambda): 0.09277444189601029,
#    gpkit.MonomialEquality(FabLine4.\lambda = QNACell1.\lambda): 0.3649652900825874,
#    gpkit.PosynomialInequality(FabLine4.W >= QNACell.W + QNACell1.W): 0.4976474693966002,
#    gpkit.PosynomialInequality(QNACell.Wq >= QNACell.rho/QNACell.\alpha·(QNACell.c2a + QNACell.c2s)/2·QNACell.t_{\eta}/QNACell.m): 0.014180596039784254,
#    gpkit.PosynomialInequality(QNACell.c2d >= QNACell.\alpha·QNACell.c2a + QNACell.rho·QNACell.c2s): 0.016011386242170085,
#    gpkit.PosynomialInequality(QNACell.\alpha + QNACell.rho <= 1): 0.07676305565395271,
#    gpkit.PosynomialInequality(QNACell.\lambda <= QNACell.rho·QNACell.m/QNACell.t_{\eta}): 0.09277444189606653,
#    gpkit.PosynomialInequality(QNACell.c2s >= Process1.cv²·QNACell.\chi_{cv}²): 0.02065433805177009,
#    gpkit.PosynomialInequality(QNACell.W >= QNACell.Wq + QNACell.t_{\eta}): 0.10478753042661226,
#    gpkit.PosynomialInequality(QNACell.t_{\eta} >= Process1.t·QNACell.\eta_t): 0.19756197232262251,
#    gpkit.PosynomialInequality(QNACell1.Wq >= QNACell1.rho/QNACell1.\alpha·(QNACell1.c2a + QNACell1.c2s)/2·QNACell1.t_{\eta}/QNACell1.m): 0.030432202585130616,
#    gpkit.PosynomialInequality(QNACell1.c2d >= QNACell1.\alpha·QNACell1.c2a + QNACell1.rho·QNACell1.c2s): 0.00953764423018424,
#    gpkit.PosynomialInequality(QNACell1.\alpha + QNACell1.rho <= 1): 0.3554276458525156,
#    gpkit.PosynomialInequality(QNACell1.\lambda <= QNACell1.rho·QNACell1.m/QNACell1.t_{\eta}): 0.3649652900826438,
#    gpkit.PosynomialInequality(QNACell1.c2s >= Process2.cv²·QNACell1.\chi_{cv}²): 0.023958460573144765,
#    gpkit.PosynomialInequality(QNACell1.W >= QNACell1.Wq + QNACell1.t_{\eta}): 0.39285993897004423,
#    gpkit.PosynomialInequality(QNACell1.t_{\eta} >= Process2.t·QNACell1.\eta_t): 0.7578252290526316,
#    gpkit.MonomialEquality(Process1.cv = Process1.\sigma/Process1.t): 0.0,
#    gpkit.MonomialEquality(Process2.cv = Process2.\sigma/Process2.t): 0.0},
#   'cost': {QNACell.m: 0.10695503878590422,
#    QNACell1.m: 0.39539749231873506,
#    FabLine4.L: 0.4976474688953607},
#   'variables': {QNACell.m: 8.500534443012242e-10,
#    QNACell1.m: -3.490393529759217e-10,
#    FabLine4.L: -5.011831505363773e-10,
#    FabLine4.\lambda: 0.9553872013751415,
#    FabLine4.W: -5.6343818499726694e-14,
#    QNACell.c2d: 3.469446951953614e-18,
#    QNACell1.c2a: 1.6756268844241723e-10,
#    QNACell1.c2d: -1.734723475976807e-18,
#    QNACell.c2a: 1.8898904385888926e-09,
#    QNACell.\lambda: 5.623279619726418e-14,
#    QNACell1.\lambda: 5.639932965095795e-14,
#    QNACell.W: 9.34190225176934e-11,
#    QNACell1.W: -9.347533858061752e-11,
#    QNACell.rho: -1.3389682002040715e-09,
#    QNACell.\alpha: 1.3390244694294617e-09,
#    QNACell.t_{\eta}: -5.980884121292718e-10,
#    QNACell.Wq: 5.981446882935559e-10,
#    QNACell.c2s: -1.889890424711105e-09,
#    Process1.cv: 0.04130867610354018,
#    QNACell.\chi_{cv}: 0.04130867610354018,
#    Process1.t: 0.19756197232262251,
#    QNACell.\eta_t: 0.19756197232262251,
#    QNACell1.rho: -1.8506501886506044e-10,
#    QNACell1.\alpha: 1.8512104349444058e-10,
#    QNACell1.t_{\eta}: -1.371680546924381e-12,
#    QNACell1.Wq: 1.4280902849161947e-12,
#    QNACell1.c2s: -1.6756268594875223e-10,
#    Process2.cv: 0.04791692114628953,
#    QNACell1.\chi_{cv}: 0.04791692114628953,
#    Process2.t: 0.7578252290526316,
#    QNACell1.\eta_t: 0.7578252290526316,
#    Process1.\sigma: 0.0,
#    Process2.\sigma: 0.0},
#   'constants': {QNACell.m: 8.500534443012242e-10,
#    QNACell1.m: -3.490393529759217e-10,
#    FabLine4.L: -5.011831505363773e-10,
#    FabLine4.\lambda: 0.9553872013751415,
#    FabLine4.W: -5.6343818499726694e-14,
#    QNACell.c2d: 3.469446951953614e-18,
#    QNACell1.c2a: 1.6756268844241723e-10,
#    QNACell1.c2d: -1.734723475976807e-18,
#    QNACell.c2a: 1.8898904385888926e-09,
#    QNACell.\lambda: 5.623279619726418e-14,
#    QNACell1.\lambda: 5.639932965095795e-14,
#    QNACell.W: 9.34190225176934e-11,
#    QNACell1.W: -9.347533858061752e-11,
#    QNACell.rho: -1.3389682002040715e-09,
#    QNACell.\alpha: 1.3390244694294617e-09,
#    QNACell.t_{\eta}: -5.980884121292718e-10,
#    QNACell.Wq: 5.981446882935559e-10,
#    QNACell.c2s: -1.889890424711105e-09,
#    Process1.cv: 0.04130867610354018,
#    QNACell.\chi_{cv}: 0.04130867610354018,
#    Process1.t: 0.19756197232262251,
#    QNACell.\eta_t: 0.19756197232262251,
#    QNACell1.rho: -1.8506501886506044e-10,
#    QNACell1.\alpha: 1.8512104349444058e-10,
#    QNACell1.t_{\eta}: -1.371680546924381e-12,
#    QNACell1.Wq: 1.4280902849161947e-12,
#    QNACell1.c2s: -1.6756268594875223e-10,
#    Process2.cv: 0.04791692114628953,
#    QNACell1.\chi_{cv}: 0.04791692114628953,
#    Process2.t: 0.7578252290526316,
#    QNACell1.\eta_t: 0.7578252290526316,
#    Process1.\sigma: 0.0,
#    Process2.\sigma: 0.0}},
#  'soltime': 0.07572317123413086}

# %% [markdown]
# This solves successfully. Add the processes again.

# %%
# line2.extend([p.cv == p.stdev/p.t for p in processes])
p = processes[0]
line2.extend([p.cv == p.stdev/p.t])
line2.solve()
# Out:
# Using solver 'cvxopt'
#  for 24 free variables
#   in 30 posynomial inequalities.
# Solving took 0.0234 seconds.
# The model ran to an infinitely low cost; bounding the right variables would prevent this.
# Since this model solved in less than a second, let's run `.debug()` automatically to check.
# `
# < DEBUGGING >
# > Trying with bounded variables and relaxed constants:
# >> Failure.
# > Trying with relaxed constraints:
# ---------------------------------------------------------------------------
# ArithmeticError                           Traceback (most recent call last)
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/cvxopt/cvxprog.py in cpl(c, F, G, h, dims, A, b, kktsolver, xnewcopy, xdot, xaxpy, xscal, ynewcopy, ydot, yaxpy, yscal, **kwargs)
#     777
# --> 778         try: f3 = kktsolver(x, z[:mnl], W)
#     779         except ArithmeticError:
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/cvxopt/cvxprog.py in kktsolver_e(x, znl, W)
#    1900         We['dnli'] = W['dnli'][1:]
# -> 1901         g = kktsolver(x[0], znl, We)
#    1902
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/cvxopt/cvxprog.py in kktsolver(x, z, W)
#    1892             f, Df, H = F(x, z)
# -> 1893             return factor(W, H, Df[1:,:])
#    1894
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/cvxopt/misc.py in factor(W, H, Df)
#    1098             K[(ldK+1)*n :: ldK+1]  -= kktreg     # Reg. term, 2x2 block (negative)
# -> 1099         lapack.sytrf(K, ipiv)
#    1100
#
# ArithmeticError: 50
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/gpkit/solvers/cvxopt.py in optimize(c, A, k, meq_idxs, use_leqs, **kwargs)
#      80     try:
# ---> 81         solution = gp(k_lse, F, g, **kwargs)
#      82     except ValueError as e:
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/cvxopt/cvxprog.py in gp(K, F, g, G, h, A, b, kktsolver, **kwargs)
#    2160
# -> 2161     return cp(Fgp, G, h, dims, A, b, kktsolver = kktsolver, options = options)
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/cvxopt/cvxprog.py in cp(F, G, h, dims, A, b, kktsolver, xnewcopy, xdot, xaxpy, xscal, ynewcopy, ydot, yaxpy, yscal, **kwargs)
#    1964
# -> 1965     sol = cpl(c, F_e, G_e, h, dims, A_e, b, kktsolver_e, xnewcopy_e,
#    1966          xdot_e, xaxpy_e, xscal_e, options = options)
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/cvxopt/cvxprog.py in cpl(c, F, G, h, dims, A, b, kktsolver, xnewcopy, xdot, xaxpy, xscal, ynewcopy, ydot, yaxpy, yscal, **kwargs)
#     781             if iters == 0:
# --> 782                 raise ValueError("Rank(A) < p or "\
#     783                     "Rank([H(x); A; Df(x); G]) < n")
#
# ValueError: Rank(A) < p or Rank([H(x); A; Df(x); G]) < n
#
# The above exception was the direct cause of the following exception:
#
# DualInfeasible                            Traceback (most recent call last)
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/gpkit/constraints/gp.py in solve(self, solver, verbosity, gen_result, **kwargs)
#     193             sys.stdout = SolverLog(original_stdout, verbosity=verbosity-2)
# --> 194             solver_out = solverfn(c=self.cs, A=self.A, meq_idxs=self.meq_idxs,
#     195                                   k=self.k, p_idxs=self.p_idxs, **solverargs)
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/gpkit/solvers/cvxopt.py in optimize(c, A, k, meq_idxs, use_leqs, **kwargs)
#      82     except ValueError as e:
# ---> 83         raise DualInfeasible() from e
#      84     if solution["status"] != "optimal":
#
# DualInfeasible:
#
# The above exception was the direct cause of the following exception:
#
# DualInfeasible                            Traceback (most recent call last)
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/gpkit/constraints/model.py in debug(self, solver, verbosity, **solveargs)
#     190             try:
# --> 191                 sol = feas.solve(**solveargs)
#     192             except InvalidGPConstraint:
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/gpkit/constraints/prog_factories.py in solvefn(self, solver, verbosity, skipsweepfailures, **solveargs)
#     115             self.program, progsolve = genfunction(self)
# --> 116             result = progsolve(solver, verbosity=verbosity, **solveargs)
#     117             if solveargs.get("process_result", True):
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/gpkit/constraints/gp.py in solve(self, solver, verbosity, gen_result, **kwargs)
#     226                     " also try another solver, or increase the verbosity.")
# --> 227             raise infeasibility.__class__(msg) from infeasibility
#     228
#
# DualInfeasible: The model ran to an infinitely low cost; bounding the right variables would prevent this. Running `.debug()` may pinpoint the trouble. You can also try another solver, or increase the verbosity.
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-74f82f66a798> in <module>
#       2 p = processes[0]
#       3 line2.extend([p.cv == p.stdev/p.t])
# ----> 4 line2.solve()
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/gpkit/constraints/prog_factories.py in solvefn(self, solver, verbosity, skipsweepfailures, **solveargs)
#     114         else:
#     115             self.program, progsolve = genfunction(self)
# --> 116             result = progsolve(solver, verbosity=verbosity, **solveargs)
#     117             if solveargs.get("process_result", True):
#     118                 self.process_result(result)
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/gpkit/constraints/gp.py in solve(self, solver, verbosity, gen_result, **kwargs)
#     222                 print(msg + "\nSince this model solved in less than a second,"
#     223                       " let's run `.debug()` automatically to check.\n`")
# --> 224                 return self.model.debug(solver=solver)
#     225             msg += (" Running `.debug()` may pinpoint the trouble. You can"
#     226                     " also try another solver, or increase the verbosity.")
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/gpkit/constraints/model.py in debug(self, solver, verbosity, **solveargs)
#     216
#     217             try:
# --> 218                 traints = ConstraintsRelaxed(self)
#     219                 feas = Model(traints.relaxvars.prod()**30 * self.cost, traints)
#     220                 try:
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/gpkit/constraints/relax.py in __init__(self, original_constraints)
#      74
#      75         with SignomialsEnabled():
# ---> 76             relaxed_constraints = [
#      77                 c.relaxed(self.relaxvars[i])
#      78                 for i, c in enumerate(original_constraints.flat())]
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/gpkit/constraints/relax.py in <listcomp>(.0)
#      75         with SignomialsEnabled():
#      76             relaxed_constraints = [
# ---> 77                 c.relaxed(self.relaxvars[i])
#      78                 for i, c in enumerate(original_constraints.flat())]
#      79
#
# ~/aa-refactor/aa-py3/lib/python3.8/site-packages/gpkit/nomials/array.py in __getitem__(self, idxs)
#      85
#      86     def __getitem__(self, idxs):
# ---> 87         out = np.ndarray.__getitem__(self, idxs)
#      88         if not getattr(out, "shape", None):
#      89             return out
#
# IndexError: index 11 is out of bounds for axis 0 with size 11

# %%
line2
# Out:
# <gpkit.FabLine object containing 11 top-level constraint(s) and 33 variable(s)>

# %% [markdown]
# GPkit struggles using CVXOPT with repeated (redundant) equality constraints!

# %% [markdown]
# ### Test to see if redundant inequality has the same issue

# %%
line3 = FabLine(cells=cells)

# %%
# Update substitutions
line3.substitutions.update({
    processes[0].t : 15*units('min'),
    processes[1].t : 30*units('min'),
})

## Process cv
line3.substitutions.update({
    p.cv : 0.5 for p in processes
})

## Production rate
line3.substitutions[line3.lam] = 50*units('count/hr')

# Add Cost
line3.cost = np.sum([c.m for c in cells]) + line3.L

# Add process constraints
line3.extend([
    p.cv == p.stdev/p.t for p in processes
])

# %%
line3.solve()
# Out:
# Using solver 'cvxopt'
#  for 24 free variables
#   in 28 posynomial inequalities.
# Solving took 0.0997 seconds.
# {'cost': 83.08909000439732,
#  'freevariables': {QNACell.m: 14.254327703807236,
#   QNACell1.m: 27.489725393424333,
#   FabLine6.L: 41.345036920587,
#   FabLine6.W: 0.8269007384118443,
#   QNACell.c2d: 0.2500000011192617,
#   QNACell1.c2a: 0.25000000282944557,
#   QNACell1.c2d: 0.25000002282169526,
#   QNACell.c2a: 0.25000004512801344,
#   QNACell.\lambda: 49.99999999999369,
#   QNACell1.\lambda: 49.99999999999369,
#   QNACell.W: 16.87449309900153,
#   QNACell1.W: 32.73955120895597,
#   QNACell.rho: 0.8769266620024282,
#   QNACell.\alpha: 0.12307333776052559,
#   QNACell.t_{\eta}: 15.000000003108672,
#   QNACell.Wq: 1.8744931083368552,
#   QNACell.c2s: 0.2500000000097678,
#   QNACell1.rho: 0.909430692472707,
#   QNACell1.\alpha: 0.09056930764420687,
#   QNACell1.t_{\eta}: 30.00000000006062,
#   QNACell1.Wq: 2.7395512106665594,
#   QNACell1.c2s: 0.2500000008638815,
#   Process1.\sigma: 7.499999999999513,
#   Process2.\sigma: 14.999999999998687},
#  'constants': {FabLine6.\lambda: 50,
#   QNACell.\chi_{cv}: 1,
#   QNACell.\eta_t: 1,
#   Process1.cv: 0.5,
#   Process1.t: 15,
#   QNACell1.\eta_t: 1,
#   QNACell1.\chi_{cv}: 1,
#   Process2.cv: 0.5,
#   Process2.t: 30},
#  'variables': {QNACell.m: 14.254327703807236,
#   QNACell1.m: 27.489725393424333,
#   FabLine6.L: 41.345036920587,
#   FabLine6.W: 0.8269007384118443,
#   QNACell.c2d: 0.2500000011192617,
#   QNACell1.c2a: 0.25000000282944557,
#   QNACell1.c2d: 0.25000002282169526,
#   QNACell.c2a: 0.25000004512801344,
#   QNACell.\lambda: 49.99999999999369,
#   QNACell1.\lambda: 49.99999999999369,
#   QNACell.W: 16.87449309900153,
#   QNACell1.W: 32.73955120895597,
#   QNACell.rho: 0.8769266620024282,
#   QNACell.\alpha: 0.12307333776052559,
#   QNACell.t_{\eta}: 15.000000003108672,
#   QNACell.Wq: 1.8744931083368552,
#   QNACell.c2s: 0.2500000000097678,
#   QNACell1.rho: 0.909430692472707,
#   QNACell1.\alpha: 0.09056930764420687,
#   QNACell1.t_{\eta}: 30.00000000006062,
#   QNACell1.Wq: 2.7395512106665594,
#   QNACell1.c2s: 0.2500000008638815,
#   Process1.\sigma: 7.499999999999513,
#   Process2.\sigma: 14.999999999998687,
#   FabLine6.\lambda: 50,
#   QNACell.\chi_{cv}: 1,
#   QNACell.\eta_t: 1,
#   Process1.cv: 0.5,
#   Process1.t: 15,
#   QNACell1.\eta_t: 1,
#   QNACell1.\chi_{cv}: 1,
#   Process2.cv: 0.5,
#   Process2.t: 30},
#  'sensitivities': {'constraints': {gpkit.MonomialEquality(FabLine6.L = FabLine6.\lambda·FabLine6.W): -0.49759886547347987,
#    gpkit.PosynomialInequality(QNACell1.c2a >= QNACell.c2d): 0.014753830103834409,
#    gpkit.PosynomialInequality(QNACell1.c2d <= QNACell.c2a): 0.01121581987690193,
#    gpkit.MonomialEquality(FabLine6.\lambda = QNACell.\lambda): 0.1527547132170564,
#    gpkit.MonomialEquality(FabLine6.\lambda = QNACell1.\lambda): 0.3033703468084167,
#    gpkit.PosynomialInequality(FabLine6.W >= QNACell.W + QNACell1.W): 0.4975988654735121,
#    gpkit.PosynomialInequality(QNACell.Wq >= QNACell.rho/QNACell.\alpha·(QNACell.c2a + QNACell.c2s)/2·QNACell.t_{\eta}/QNACell.m): 0.018800032319758287,
#    gpkit.PosynomialInequality(QNACell.c2d >= QNACell.\alpha·QNACell.c2a + QNACell.rho·QNACell.c2s): 0.014753830103834405,
#    gpkit.PosynomialInequality(QNACell.\alpha + QNACell.rho <= 1): 0.13800088311328648,
#    gpkit.PosynomialInequality(QNACell.\lambda <= QNACell.rho·QNACell.m/QNACell.t_{\eta}): 0.15275471321708864,
#    gpkit.PosynomialInequality(QNACell.c2s >= Process1.cv²·QNACell.\chi_{cv}²): 0.022338042546690775,
#    gpkit.PosynomialInequality(QNACell.W >= QNACell.Wq + QNACell.t_{\eta}): 0.16924096269605926,
#    gpkit.PosynomialInequality(QNACell.t_{\eta} >= Process1.t·QNACell.\eta_t): 0.32199567591311573,
#    gpkit.PosynomialInequality(QNACell1.Wq >= QNACell1.rho/QNACell1.\alpha·(QNACell1.c2a + QNACell1.c2s)/2·QNACell1.t_{\eta}/QNACell1.m): 0.027476042181320777,
#    gpkit.PosynomialInequality(QNACell1.c2d >= QNACell1.\alpha·QNACell1.c2a + QNACell1.rho·QNACell1.c2s): 0.011215819876901928,
#    gpkit.PosynomialInequality(QNACell1.\alpha + QNACell1.rho <= 1): 0.29215452693157923,
#    gpkit.PosynomialInequality(QNACell1.\lambda <= QNACell1.rho·QNACell1.m/QNACell1.t_{\eta}): 0.30337034680844893,
#    gpkit.PosynomialInequality(QNACell1.c2s >= Process2.cv²·QNACell1.\chi_{cv}²): 0.023938031954388286,
#    gpkit.PosynomialInequality(QNACell1.W >= QNACell1.Wq + QNACell1.t_{\eta}): 0.32835790277748517,
#    gpkit.PosynomialInequality(QNACell1.t_{\eta} >= Process2.t·QNACell1.\eta_t): 0.6317282495859017,
#    gpkit.MonomialEquality(Process1.cv = Process1.\sigma/Process1.t): 0.0,
#    gpkit.MonomialEquality(Process2.cv = Process2.\sigma/Process2.t): 0.0},
#   'cost': {QNACell.m: 0.17155474564410775,
#    QNACell1.m: 0.3308463889486469,
#    FabLine6.L: 0.4975988654072454},
#   'variables': {QNACell.m: 1.0726081134393439e-10,
#    QNACell1.m: -4.112282736556949e-11,
#    FabLine6.L: -6.623446235920483e-11,
#    FabLine6.\lambda: 0.9537239254989529,
#    FabLine6.W: -3.219646771412954e-14,
#    QNACell.c2d: 3.469446951953614e-18,
#    QNACell1.c2a: 8.888949082005992e-11,
#    QNACell1.c2d: 1.734723475976807e-18,
#    QNACell.c2a: 5.346345094067728e-10,
#    QNACell.\lambda: 3.22519788653608e-14,
#    QNACell1.\lambda: 3.22519788653608e-14,
#    QNACell.W: -8.4632856278688e-12,
#    QNACell1.W: 8.430922626700976e-12,
#    QNACell.rho: -3.863207254095613e-10,
#    QNACell.\alpha: 3.863529739189797e-10,
#    QNACell.t_{\eta}: -1.3907386353650963e-10,
#    QNACell.Wq: 1.3910601143196644e-10,
#    QNACell.c2s: -5.346345206824754e-10,
#    Process1.cv: 0.04467608509338155,
#    QNACell.\chi_{cv}: 0.04467608509338155,
#    Process1.t: 0.32199567591311573,
#    QNACell.\eta_t: 0.32199567591311573,
#    QNACell1.rho: -9.292489000500836e-11,
#    QNACell1.\alpha: 9.295716627000239e-11,
#    QNACell1.t_{\eta}: -6.56030785251005e-13,
#    QNACell1.Wq: 6.884631753578674e-13,
#    QNACell1.c2s: -8.888947564122951e-11,
#    Process2.cv: 0.04787606390877657,
#    QNACell1.\chi_{cv}: 0.04787606390877657,
#    Process2.t: 0.6317282495859017,
#    QNACell1.\eta_t: 0.6317282495859017,
#    Process1.\sigma: 0.0,
#    Process2.\sigma: 0.0},
#   'constants': {QNACell.m: 1.0726081134393439e-10,
#    QNACell1.m: -4.112282736556949e-11,
#    FabLine6.L: -6.623446235920483e-11,
#    FabLine6.\lambda: 0.9537239254989529,
#    FabLine6.W: -3.219646771412954e-14,
#    QNACell.c2d: 3.469446951953614e-18,
#    QNACell1.c2a: 8.888949082005992e-11,
#    QNACell1.c2d: 1.734723475976807e-18,
#    QNACell.c2a: 5.346345094067728e-10,
#    QNACell.\lambda: 3.22519788653608e-14,
#    QNACell1.\lambda: 3.22519788653608e-14,
#    QNACell.W: -8.4632856278688e-12,
#    QNACell1.W: 8.430922626700976e-12,
#    QNACell.rho: -3.863207254095613e-10,
#    QNACell.\alpha: 3.863529739189797e-10,
#    QNACell.t_{\eta}: -1.3907386353650963e-10,
#    QNACell.Wq: 1.3910601143196644e-10,
#    QNACell.c2s: -5.346345206824754e-10,
#    Process1.cv: 0.04467608509338155,
#    QNACell.\chi_{cv}: 0.04467608509338155,
#    Process1.t: 0.32199567591311573,
#    QNACell.\eta_t: 0.32199567591311573,
#    QNACell1.rho: -9.292489000500836e-11,
#    QNACell1.\alpha: 9.295716627000239e-11,
#    QNACell1.t_{\eta}: -6.56030785251005e-13,
#    QNACell1.Wq: 6.884631753578674e-13,
#    QNACell1.c2s: -8.888947564122951e-11,
#    Process2.cv: 0.04787606390877657,
#    QNACell1.\chi_{cv}: 0.04787606390877657,
#    Process2.t: 0.6317282495859017,
#    QNACell1.\eta_t: 0.6317282495859017,
#    Process1.\sigma: 0.0,
#    Process2.\sigma: 0.0}},
#  'soltime': 0.09966254234313965}

# %% [markdown]
# Add a redundant inequality constraint

# %%
c = cells[0]

# %%
line3.extend([
    c.W >= c.Wq + c.tnu
])

# %%
line3
# Out:
# <gpkit.FabLine object containing 11 top-level constraint(s) and 33 variable(s)>

# %%
line3.solve()
# Out:
# Using solver 'cvxopt'
#  for 24 free variables
#   in 29 posynomial inequalities.
# Solving took 0.15 seconds.
# {'cost': 83.0890899811816,
#  'freevariables': {QNACell.m: 14.25432768112975,
#   QNACell1.m: 27.489725397344543,
#   FabLine6.L: 41.345036911505886,
#   FabLine6.W: 0.8269007382303932,
#   QNACell.c2d: 0.2500000044431339,
#   QNACell1.c2a: 0.25000000886279805,
#   QNACell1.c2d: 0.25000000877628964,
#   QNACell.c2a: 0.25000001794365256,
#   QNACell.\lambda: 49.999999999983345,
#   QNACell1.\lambda: 49.999999999983345,
#   QNACell.W: 16.87449309264563,
#   QNACell1.W: 32.73955121178175,
#   QNACell.rho: 0.8769266637043797,
#   QNACell.\alpha: 0.12307333565261638,
#   QNACell.t_{\eta}: 15.000000005968246,
#   QNACell.Wq: 1.8744930797636512,
#   QNACell.c2s: 0.25000000000715883,
#   QNACell1.rho: 0.9094306923402001,
#   QNACell1.\alpha: 0.09056930788469496,
#   QNACell1.t_{\eta}: 30.000000000026635,
#   QNACell1.Wq: 2.739551216711311,
#   QNACell1.c2s: 0.2500000001336316,
#   Process1.\sigma: 7.499999999998714,
#   Process2.\sigma: 14.999999999996543},
#  'constants': {FabLine6.\lambda: 50,
#   QNACell.\chi_{cv}: 1,
#   QNACell.\eta_t: 1,
#   Process1.cv: 0.5,
#   Process1.t: 15,
#   QNACell1.\eta_t: 1,
#   QNACell1.\chi_{cv}: 1,
#   Process2.cv: 0.5,
#   Process2.t: 30},
#  'variables': {QNACell.m: 14.25432768112975,
#   QNACell1.m: 27.489725397344543,
#   FabLine6.L: 41.345036911505886,
#   FabLine6.W: 0.8269007382303932,
#   QNACell.c2d: 0.2500000044431339,
#   QNACell1.c2a: 0.25000000886279805,
#   QNACell1.c2d: 0.25000000877628964,
#   QNACell.c2a: 0.25000001794365256,
#   QNACell.\lambda: 49.999999999983345,
#   QNACell1.\lambda: 49.999999999983345,
#   QNACell.W: 16.87449309264563,
#   QNACell1.W: 32.73955121178175,
#   QNACell.rho: 0.8769266637043797,
#   QNACell.\alpha: 0.12307333565261638,
#   QNACell.t_{\eta}: 15.000000005968246,
#   QNACell.Wq: 1.8744930797636512,
#   QNACell.c2s: 0.25000000000715883,
#   QNACell1.rho: 0.9094306923402001,
#   QNACell1.\alpha: 0.09056930788469496,
#   QNACell1.t_{\eta}: 30.000000000026635,
#   QNACell1.Wq: 2.739551216711311,
#   QNACell1.c2s: 0.2500000001336316,
#   Process1.\sigma: 7.499999999998714,
#   Process2.\sigma: 14.999999999996543,
#   FabLine6.\lambda: 50,
#   QNACell.\chi_{cv}: 1,
#   QNACell.\eta_t: 1,
#   Process1.cv: 0.5,
#   Process1.t: 15,
#   QNACell1.\eta_t: 1,
#   QNACell1.\chi_{cv}: 1,
#   Process2.cv: 0.5,
#   Process2.t: 30},
#  'sensitivities': {'constraints': {gpkit.MonomialEquality(FabLine6.L = FabLine6.\lambda·FabLine6.W): -0.49759886551354515,
#    gpkit.PosynomialInequality(QNACell1.c2a >= QNACell.c2d): 0.014753830263510726,
#    gpkit.PosynomialInequality(QNACell1.c2d <= QNACell.c2a): 0.011215819452235548,
#    gpkit.MonomialEquality(FabLine6.\lambda = QNACell.\lambda): 0.15275471329401352,
#    gpkit.MonomialEquality(FabLine6.\lambda = QNACell1.\lambda): 0.30337034689172354,
#    gpkit.PosynomialInequality(FabLine6.W >= QNACell.W + QNACell1.W): 0.49759886551363036,
#    gpkit.PosynomialInequality(QNACell.Wq >= QNACell.rho/QNACell.\alpha·(QNACell.c2a + QNACell.c2s)/2·QNACell.t_{\eta}/QNACell.m): 0.01880003206443185,
#    gpkit.PosynomialInequality(QNACell.c2d >= QNACell.\alpha·QNACell.c2a + QNACell.rho·QNACell.c2s): 0.014753830263510726,
#    gpkit.PosynomialInequality(QNACell.\alpha + QNACell.rho <= 1): 0.13800088303067296,
#    gpkit.PosynomialInequality(QNACell.\lambda <= QNACell.rho·QNACell.m/QNACell.t_{\eta}): 0.15275471329409865,
#    gpkit.PosynomialInequality(QNACell.c2s >= Process1.cv²·QNACell.\chi_{cv}²): 0.022338042875707027,
#    gpkit.PosynomialInequality(QNACell.W >= QNACell.Wq + QNACell.t_{\eta}): 0.08462048131865306,
#    gpkit.PosynomialInequality(QNACell.t_{\eta} >= Process1.t·QNACell.\eta_t): 0.32199567593123457,
#    gpkit.PosynomialInequality(QNACell1.Wq >= QNACell1.rho/QNACell1.\alpha·(QNACell1.c2a + QNACell1.c2s)/2·QNACell1.t_{\eta}/QNACell1.m): 0.027476042236370936,
#    gpkit.PosynomialInequality(QNACell1.c2d >= QNACell1.\alpha·QNACell1.c2a + QNACell1.rho·QNACell1.c2s): 0.011215819452235544,
#    gpkit.PosynomialInequality(QNACell1.\alpha + QNACell1.rho <= 1): 0.29215452743965825,
#    gpkit.PosynomialInequality(QNACell1.\lambda <= QNACell1.rho·QNACell1.m/QNACell1.t_{\eta}): 0.30337034689180864,
#    gpkit.PosynomialInequality(QNACell1.c2s >= Process2.cv²·QNACell1.\chi_{cv}²): 0.023938031425095752,
#    gpkit.PosynomialInequality(QNACell1.W >= QNACell1.Wq + QNACell1.t_{\eta}): 0.3283579028764943,
#    gpkit.PosynomialInequality(QNACell1.t_{\eta} >= Process2.t·QNACell1.\eta_t): 0.6317282497682177,
#    gpkit.MonomialEquality(Process1.cv = Process1.\sigma/Process1.t): 0.0,
#    gpkit.MonomialEquality(Process2.cv = Process2.\sigma/Process2.t): 0.0,
#    gpkit.PosynomialInequality(QNACell.W >= QNACell.Wq + QNACell.t_{\eta}): 0.08462048131865309},
#   'cost': {QNACell.m: 0.17155474542865612,
#    QNACell1.m: 0.3308463891066753,
#    FabLine6.L: 0.4975988654646685},
#   'variables': {QNACell.m: 7.01256275270623e-11,
#    QNACell1.m: -2.1504298342023276e-11,
#    FabLine6.L: -4.8876624969551585e-11,
#    FabLine6.\lambda: 0.9537239256992822,
#    FabLine6.W: -8.520961713998076e-14,
#    QNACell.c2d: 0.0,
#    QNACell1.c2a: 1.316941965635171e-10,
#    QNACell1.c2d: 3.469446951953614e-18,
#    QNACell.c2a: 1.3678036394487725e-10,
#    QNACell.\lambda: 8.512635041313388e-14,
#    QNACell1.\lambda: 8.509859483751825e-14,
#    QNACell.W: 1.2230605417329343e-11,
#    QNACell1.W: -1.2400636073550686e-11,
#    QNACell.rho: -1.635888369211358e-10,
#    QNACell.\alpha: 1.6367388694371598e-10,
#    QNACell.t_{\eta}: -1.298115226422425e-10,
#    QNACell.Wq: 1.2998172677081143e-10,
#    QNACell.c2s: -1.3678036481223899e-10,
#    Process1.cv: 0.04467608575141405,
#    QNACell.\chi_{cv}: 0.04467608575141405,
#    Process1.t: 0.32199567593123457,
#    QNACell.\eta_t: 0.32199567593123457,
#    QNACell1.rho: -1.403595573101768e-10,
#    QNACell1.\alpha: 1.4044477039676373e-10,
#    QNACell1.t_{\eta}: -9.418688051709978e-12,
#    QNACell1.Wq: 9.503890729956055e-12,
#    QNACell1.c2s: -1.3169419374459146e-10,
#    Process2.cv: 0.047876062850191504,
#    QNACell1.\chi_{cv}: 0.047876062850191504,
#    Process2.t: 0.6317282497682177,
#    QNACell1.\eta_t: 0.6317282497682177,
#    Process1.\sigma: 0.0,
#    Process2.\sigma: 0.0},
#   'constants': {QNACell.m: 7.01256275270623e-11,
#    QNACell1.m: -2.1504298342023276e-11,
#    FabLine6.L: -4.8876624969551585e-11,
#    FabLine6.\lambda: 0.9537239256992822,
#    FabLine6.W: -8.520961713998076e-14,
#    QNACell.c2d: 0.0,
#    QNACell1.c2a: 1.316941965635171e-10,
#    QNACell1.c2d: 3.469446951953614e-18,
#    QNACell.c2a: 1.3678036394487725e-10,
#    QNACell.\lambda: 8.512635041313388e-14,
#    QNACell1.\lambda: 8.509859483751825e-14,
#    QNACell.W: 1.2230605417329343e-11,
#    QNACell1.W: -1.2400636073550686e-11,
#    QNACell.rho: -1.635888369211358e-10,
#    QNACell.\alpha: 1.6367388694371598e-10,
#    QNACell.t_{\eta}: -1.298115226422425e-10,
#    QNACell.Wq: 1.2998172677081143e-10,
#    QNACell.c2s: -1.3678036481223899e-10,
#    Process1.cv: 0.04467608575141405,
#    QNACell.\chi_{cv}: 0.04467608575141405,
#    Process1.t: 0.32199567593123457,
#    QNACell.\eta_t: 0.32199567593123457,
#    QNACell1.rho: -1.403595573101768e-10,
#    QNACell1.\alpha: 1.4044477039676373e-10,
#    QNACell1.t_{\eta}: -9.418688051709978e-12,
#    QNACell1.Wq: 9.503890729956055e-12,
#    QNACell1.c2s: -1.3169419374459146e-10,
#    Process2.cv: 0.047876062850191504,
#    QNACell1.\chi_{cv}: 0.047876062850191504,
#    Process2.t: 0.6317282497682177,
#    QNACell1.\eta_t: 0.6317282497682177,
#    Process1.\sigma: 0.0,
#    Process2.\sigma: 0.0}},
#  'soltime': 0.14959335327148438}

# %% [markdown]
# Seems to work fine with redundant inequality constraints.

# %% [markdown]
# ## Prep model for creating GPkit Git Issue
# Redundant equality constraint causes issues with CVXOPT

# %% [markdown]
# When using CVXOPT, a redundant equality constraint will fail to solve and send the model into debug mode (see the example below). The model is feasible as demonstrated by the successful solve on the first go. Once in debug mode, the model is solved successfully with relaxed constraints but shows 0% relaxation.
#
# As far as I have tried, redundant inequality constraints do not seem to have this issue.
#
# Thoughts?
#
# --Environment Information--
#
# Python 3.
# GPkit
# CVXOPT

# %%
from gpkit import Model, Variable

a = Variable('a', 1)
b = Variable('b')
c = Variable('c', 2)
d = Variable('d')
z = Variable('z', 0.5)

# create a simple GP with equality constraints
const = [
    z == b/a,
    z == d/c,
]

# simple cost
cost = a + b + c + d

# create a model
m = Model(cost, const)

# solve the first version of the model (solves successfully)
m.solve(solver='cvxopt')

# add a redundant equality constraint
m.extend([
    z == b/a
])

# solver will fail and attempt to debug
m.solve(solver='cvxopt')
# Out:
# Using solver 'cvxopt'
#  for 2 free variables
#   in 5 posynomial inequalities.
# Solving took 0.0462 seconds.
# Using solver 'cvxopt'
#  for 2 free variables
#   in 7 posynomial inequalities.
# Solving took 0.00747 seconds.
# The model ran to an infinitely low cost; bounding the right variables would prevent this.
# Since this model solved in less than a second, let's run `.debug()` automatically to check.
# `
# < DEBUGGING >
# > Trying with bounded variables and relaxed constants:
# >> Failure.
# > Trying with relaxed constraints:
#
# Solves with these constraints relaxed:
#    0:    0% relaxed, from z = b/a
#                      to z <= a^-1·b
#
# >> Success!
# {'cost': 4.500001313472465,
#  'freevariables': {Relax9.C[:]: array([1., 1., 1.]),
#   b: 0.49999999979144816,
#   d: 0.9999999984845993},
#  'constants': {z: 0.5, a: 1, c: 2},
#  'variables': {Relax9.C[:]: array([1., 1., 1.]),
#   b: 0.49999999979144816,
#   d: 0.9999999984845993,
#   z: 0.5,
#   a: 1,
#   c: 2},
#  'sensitivities': {'constraints': {gpkit.PosynomialInequality(Relax9.C[0] >= 1): 10.00081631760442,
#    gpkit.PosynomialInequality(Relax9.C[1] >= 1): 10.017579290927342,
#    gpkit.PosynomialInequality(Relax9.C[2] >= 1): 10.00081631760442,
#    gpkit.PosynomialInequality(z <= Relax9.C[0]·b/a): 10.027369616167594,
#    gpkit.PosynomialInequality(Relax9.C[0]·z >= b/a): 9.97181406622798,
#    gpkit.PosynomialInequality(z <= Relax9.C[1]·d/c): 10.102321466934313,
#    gpkit.PosynomialInequality(Relax9.C[1]·z >= d/c): 9.880099242138336,
#    gpkit.PosynomialInequality(z <= Relax9.C[2]·b/a): 10.027369616167594,
#    gpkit.PosynomialInequality(Relax9.C[2]·z >= b/a): 9.97181406622798},
#   'cost': {Relax9.C[0]: 30.0,
#    Relax9.C[1]: 30.0,
#    Relax9.C[2]: 30.0,
#    a: 0.11111111110733297,
#    b: 0.2222222219705999,
#    c: 0.6666666669220671},
#   'variables': {Relax9.C[:]: array([8.88178420e-15, 7.10542736e-15, 8.88178420e-15]),
#    a: 0.22222221098656014,
#    b: 0.11111112209137275,
#    c: 0.8888888917180449,
#    z: 0.3333333246752055,
#    d: -0.22222222479597775},
#   'constants': {Relax9.C[:]: array([8.88178420e-15, 7.10542736e-15, 8.88178420e-15]),
#    a: 0.22222221098656014,
#    b: 0.11111112209137275,
#    c: 0.8888888917180449,
#    z: 0.3333333246752055,
#    d: -0.22222222479597775}},
#  'soltime': 0.01817941665649414}
