# %% [markdown]
# # Test using variables with same name in substitution
# Variables with the same name are created (but are different objects)

# %%
from gpkit import Variable, Model

# %%
a = Variable('x', 5)
b = Variable('x', 10)
c = Variable('y')

# %%
m = Model(c, [c >= a, c >= b])

# %%
m
# Out:
# <gpkit.Model object containing 2 top-level constraint(s) and 2 variable(s)>

# %%
m.substitutions
# Out:
# {x: 10}

# %%
a.key
# Out:
# x

# %%
type(a.varkeys)
# Out:
# gpkit.keydict.KeySet

# %%
b.varkeys
# Out:
# {x}

# %%
a is b
# Out:
# False

# %%
not(a != b)
# Out:
# True

# %% [markdown]
# The variables have the same key so they are the same variable

# %% [markdown]
# Exploit this fact for the variants

# %% [markdown]
# _may be able to exploit when trying to substitute new variables (instead of just number)_

# %%
help(a.sub)
# Out:
# Help on method sub in module gpkit.nomials.variables:
#
# sub(*args, **kwargs) method of gpkit.nomials.variables.Variable instance
#     Same as nomial substitution, but also allows single-argument calls
#
#     Example
#     -------
#     x = Variable('x')
#     assert x.sub(3) == Variable('x', value=3)

# %%
print('test // thing')
# Out:
# test // thing

# %% [markdown]
# ## Substitute Nomials or Variables

# %%
m
# Out:
# <gpkit.Model object containing 2 top-level constraint(s) and 2 variable(s)>

# %%
z = Variable('z', 7)

# %%
m2 = Model(c, [c >= b, c>= z])

# %%
m2.substitutions[z] = 7

# %%
m2.solve()
# Out:
# Using solver 'mosek_cli'
#  for 1 free variables
#   in 3 posynomial inequalities.
# Solving took 0.0223 seconds.
# {'constants': {x: 10, z: 7},
#  'cost': 10.0,
#  'freevariables': {y: 9.999999070059587},
#  'sensitivities': {'constants': {x: 1.0, y: 0.0, z: 0.0},
#   'constraints': {gpkit.PosynomialInequality(y >= x): 1.0,
#    gpkit.PosynomialInequality(y >= z): 0.0},
#   'cost': {y: 1.0},
#   'variables': {x: 1.0, y: 0.0, z: 0.0}},
#  'soltime': 0.022290945053100586,
#  'variables': {x: 10, y: 9.999999070059587, z: 7}}

# %%
m2.substitutions[b] = z

# %%
m2.substitutions
# Out:
# {x: gpkit.Variable(z), z: 7}

# %%
m2.solve()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-9bed307547c0> in <module>
# ----> 1 m2.solve()
#
# ~/aa-refactor/aa-venv/py3-dev/venv/lib/python3.5/site-packages/gpkit/constraints/prog_factories.py in solvefn(self, solver, verbosity, skipsweepfailures, **solveargs)
#     113                       constants, sweep, linked, solver, verbosity, **solveargs)
#     114         else:
# --> 115             self.program, progsolve = genfunction(self)
#     116             result = progsolve(solver, verbosity=verbosity, **solveargs)
#     117             if solveargs.get("process_result", True):
#
# ~/aa-refactor/aa-venv/py3-dev/venv/lib/python3.5/site-packages/gpkit/constraints/prog_factories.py in programfn(self, constants, **initargs)
#      69             if linked:
#      70                 evaluate_linked(constants, linked)
# ...

# %% [markdown]
# _Cannot substitute variables_

# %%
test = {'one' : 1}

# %%
'one' in test
# Out:
# True

# %%
test = {'one' : 1}

# %%
test2 = [7]

# %%
for a, b in zip(list(test.keys()), test2):
    print(a)
# Out:
# one
