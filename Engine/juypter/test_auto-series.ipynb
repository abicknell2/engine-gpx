# %% [markdown]
# Test automatically creating a process in series for processes that are in the same cell

# %%
from interactive_generators import createModelFromDict

# %%
import json

# %%
inputjson = '''
    {"partName":"Part Name","design":{"parameters":[],"plyBook":{"stack":[[{"value":0},{"value":0}],[{"value":0},{"value":0}]],"length":[[{"value":0}],[{"value":0}]],"width":[[{"value":0},{"value":0}]]},"designModule":"Fuselage"},"manufacturing":{"process":"Infusion (STL)","quantity":1000,"rate":40,"line":"cell","processChain":[],"cells":[]},"type":"custom","costComponents":[{"name":"Infuse and Cure","value":215669.97647273724},{"name":"Clean Tool","value":5761.551028879034},{"name":"AFP","value":1470590.8995155105},{"name":"Layup Mandrel","value":353677.1914535163},{"name":"Total","value":2045699.618470643}],"prevCostComponents":[{"name":"Infuse and Cure","value":215669.52985004874},{"name":"Clean Tool","value":2669.2950148451346},{"name":"AFP","value":1470589.6357525927},{"name":"Layup Mandrel","value":326600.1764935065},{"name":"Total","value":2015528.637110993}],"options":[],"sensitivities":[{"fill":-0.0024669242340581267,"name":"Clean Tool Std. Dev.","secondaryUnit":"$ per unit per percent change in input","secondaryValue":5.048216482278143,"tags":{"model":"Manufacturing"},"unit":"%/%","value":0.0024669242340581267},{"fill":-0.002816419975621626,"name":"Clean Tool Cell Cost","secondaryUnit":"$ per unit per percent change in input","secondaryValue":5.763410787270854,"tags":{"model":"Manufacturing"},"unit":"%/%","value":0.002816419975621626},{"fill":-0.01259309205462255,"name":"Clean Tool Time","secondaryUnit":"$ per unit per percent change in input","secondaryValue":25.770007037635494,"tags":{"model":"Manufacturing"},"unit":"%/%","value":0.01259309205462255},{"fill":-0.10542602379541732,"name":"Infuse and Cure Cell Cost","secondaryUnit":"$ per unit per percent change in input","secondaryValue":215.73965816922333,"tags":{"model":"Manufacturing"},"unit":"%/%","value":0.10542602379541732},{"fill":-0.11308481722554045,"name":"cv","secondaryUnit":"$ per unit per percent change in input","secondaryValue":231.4123110600296,"tags":{"model":"Manufacturing"},"unit":"%/%","value":0.11308481722554045},{"fill":-0.14113651283855766,"name":"Cure Time","secondaryUnit":"$ per unit per percent change in input","secondaryValue":288.81619489011007,"tags":{"model":"Manufacturing"},"unit":"%/%","value":0.14113651283855766},{"fill":-0.17288813496969255,"name":"Layup Mandrel Tool Cost","secondaryUnit":"$ per unit per percent change in input","secondaryValue":353.7914624595501,"tags":{"model":"Manufacturing"},"unit":"%/%","value":0.17288813496969255},{"fill":-0.7188694212593826,"name":"AFP Cell Cost","secondaryUnit":"$ per unit per percent change in input","secondaryValue":1471.0660387966566,"tags":{"model":"Manufacturing"},"unit":"%/%","value":0.7188694212593826},{"fill":-0.7863506943736758,"name":"Layup Rate","secondaryUnit":"$ per unit per percent change in input","secondaryValue":1609.1570553254849,"tags":{"model":"Manufacturing"},"unit":"%/%","value":0.7863506943736758},{"fill":-0.7863506943736758,"name":"Part Mass","secondaryUnit":"$ per unit per percent change in input","secondaryValue":1609.1570553254849,"tags":{"model":"Design"},"unit":"%/%","value":0.7863506943736758}],"processResults":[{"processTime":2,"stdev":30,"type":"Clean Tool"},{"processTime":350,"stdev":87.5000000243069,"type":"Cure"},{"processTime":661.3867865620078,"stdev":165.34669669434192,"type":"Layup"}],"cellResults":[{"cellTimeSensitivity":0.7863506943736761,"cellVariationSensitivity":0.062176895092843715,"name":"AFP","numWorkstations":1.470590899497944,"queueingTime":417.801458425288,"queueingTimeUnit":"minute","utilization":0.9369629168626167,"wip":2.2483088438064796},{"cellTimeSensitivity":0.14113651283855766,"cellVariationSensitivity":0.0509079221327727,"name":"Infuse and Cure","numWorkstations":0.8626799057702119,"queueingTime":138.48440090148677,"queueingTimeUnit":"minute","utilization":0.8452343238390273,"wip":1.0176758354308488}],"probabilities":{},"modules":[{"name":"Fuselage","type":"design","design":[{"name":"Part Mass","sign":"=","unit":"kg","value":100}],"modelInputs":[{"name":"Part Perimeter","key":"perimeter // Fuselage","unit":"m"},{"name":"Part Length","key":"length // Fuselage","unit":"m"},{"name":"Part Width","key":"width // Fuselage","unit":"m"},{"name":"Part Thickness","key":"thickness // Fuselage","unit":"m"},{"name":"Total Surface Area","key":"surfaceArea // Fuselage","unit":"m^2"},{"name":"Layup Area / Layer","key":"layupArea // Fuselage","unit":"m^2"},{"name":"Hole Count","key":"holeCount // Fuselage","unit":"count"},{"name":"Cutout Perimeter","key":"cutoutPerimeter // Fuselage","unit":"m"},{"name":"Part Min. Curvature Radius","key":"curvature // Fuselage","unit":"m"},{"name":"Part Mass","sign":"=","unit":"kg","value":100}]},{"name":"Infusion (STL)","type":"manufacturing","manufacturing":{"processTypes":[],"processChain":[{"#":"","type":"Layup","cell":1},{"#":"","type":"Prep","cell":2},{"#":"","type":"Bag","cell":2},{"#":"","type":"Cure","cell":3}],"routes":[{"prev":3,"next":4,"%":""},{"prev":4,"next":2,"%":""}],"tools":[{"name":"Layup Mandrel","first":1,"last":3}],"cells":[{"id":"","name":"AFP","workstationCapacity":1},{"id":"","name":"Bag and Prep","workstationCapacity":1},{"id":"","name":"Infuse and Cure","workstationCapacity":1},{"id":"","name":"Clean Tool","workstationCapacity":1}],"variables":[{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":350},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Layup Mandrel Tool Cost","sign":"=","unit":"$","value":100000},{"name":"AFP Head Count","sign":"=","unit":"count","value":1},{"name":"AFP Cell Cost","sign":"=","unit":"$","value":1000000},{"name":"Infuse and Cure Cell Cost","sign":"=","unit":"$","value":250000},{"name":"Infuse and Cure Head Count","sign":"=","unit":"count","value":2},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Clean Tool Time","sign":"=","unit":"hr","value":2},{"name":"Clean Tool Std. Dev.","sign":"=","unit":"min","value":30},{"name":"Clean Tool Head Count","sign":"=","unit":"count","value":3},{"name":"Clean Tool Cell Cost","sign":"=","unit":"$","value":10000},{"name":"Bag and Prep Cell Cost","sign":"=","unit":"$","value":25000},{"name":"Bag and Prep Head Count","sign":"=","unit":"count","value":4},{"name":"Bag Time","sign":"=","unit":"min","value":120},{"name":"Bag Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Bag Time"]},{"name":"Prep Time","sign":"=","unit":"min","value":80},{"name":"Prep Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Prep Time"]}],"secProcesses":[{"#":"","type":"Clean Tool","cell":4}],"costs":[]},"modelInputs":[{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":350},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Layup Mandrel Tool Cost","sign":"=","unit":"$","value":100000},{"name":"AFP Head Count","sign":"=","unit":"count","value":1},{"name":"AFP Cell Cost","sign":"=","unit":"$","value":1000000},{"name":"Infuse and Cure Cell Cost","sign":"=","unit":"$","value":250000},{"name":"Infuse and Cure Head Count","sign":"=","unit":"count","value":2},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Clean Tool Time","sign":"=","unit":"hr","value":2},{"name":"Clean Tool Std. Dev.","sign":"=","unit":"min","value":30},{"name":"Clean Tool Head Count","sign":"=","unit":"count","value":3},{"name":"Clean Tool Cell Cost","sign":"=","unit":"$","value":10000},{"name":"Bag and Prep Cell Cost","sign":"=","unit":"$","value":25000},{"name":"Bag and Prep Head Count","sign":"=","unit":"count","value":4},{"name":"Bag Time","sign":"=","unit":"min","value":120},{"name":"Bag Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Bag Time"]},{"name":"Prep Time","sign":"=","unit":"min","value":80},{"name":"Prep Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Prep Time"]}]}],"ui":{"editProductionDetails":false,"showModal":false,"loading":false,"numsolves":5,"developerView":false},"allVariables":[{"name":"Layup Std. Dev.","sensitivity":-1.3877787807814457e-17,"source":"Calculated Value","unit":"minute","value":165.34669669434192},{"name":"Infuse and Cure Cell Variation Sensitivity","sensitivity":0.0509079221327727,"source":"From Assumption","unit":"","value":1},{"name":"AFP Cell Queueing Time","sensitivity":7.359710063603586e-12,"source":"Calculated Value","unit":"minute","value":417.801458425288},{"name":"Infuse and Cure Cell Cost","sensitivity":0.10542602379541732,"source":"From Assumption","unit":"$","value":250000},{"name":"AFP Cell Variation Sensitivity","sensitivity":0.062176895092843715,"source":"From Assumption","unit":"","value":1},{"name":"Clean Tool Time","sensitivity":0.01259309205462255,"source":"From Assumption","unit":"hour","value":2},{"name":"Total Recurring Cost","sensitivity":2.997420900353008e-9,"source":"Calculated Value","unit":"$","value":0.6609598774673264},{"name":"Layup Mandrel Tool Cost","sensitivity":0.17288813496969255,"source":"From Assumption","unit":"$","value":100000},{"name":"Infuse and Cure Cell Time Sensitivity","sensitivity":0.14113651283855766,"source":"From Assumption","unit":"","value":1},{"name":"Part Mass","sensitivity":0.7863506943736758,"source":"From Assumption","unit":"kilogram","value":100},{"name":"Clean Tool Cell Cost","sensitivity":0.002816419975621626,"source":"From Assumption","unit":"$","value":10000},{"name":"Infuse and Cure Cell Queueing Time","sensitivity":5.2334057226710584e-12,"source":"Calculated Value","unit":"minute","value":138.48440090148677},{"name":"AFP Subtotal Cell Cost","sensitivity":-6.28157081905556e-10,"source":"Calculated Value","unit":"$","value":1470590.8995155105},{"name":"Layup Time","sensitivity":3.885780586188048e-16,"source":"Calculated Value","unit":"minute","value":661.3867865620078},{"name":"Cure Std. Dev.","sensitivity":0,"source":"Calculated Value","unit":"minute","value":87.5000000243069},{"name":"Clean Tool Subtotal Cell Cost","sensitivity":8.599976061146597e-10,"source":"Calculated Value","unit":"$","value":5761.551028879034},{"name":"Layup Mandrel Subtotal Tool Cost","sensitivity":-1.4277992677058648e-10,"source":"Calculated Value","unit":"$","value":353677.1914535163},{"name":"AFP Cell Cost","sensitivity":0.7188694212593826,"source":"From Assumption","unit":"$","value":1000000},{"name":"Total Unit Cost","sensitivity":3.785860513971784e-14,"source":"Calculated Value","unit":"$","value":2046.3605702124673},{"name":"cv","sensitivity":0.11308481722554045,"source":"From Assumption","unit":"","value":0.25},{"name":"Cure Time","sensitivity":0.14113651283855766,"source":"From Assumption","unit":"minute","value":350},{"name":"AFP Cell Workstations","sensitivity":-3.7969627442180354e-14,"source":"Calculated Value","unit":"count","value":1.470590899497944},{"name":"Total Non-Recurring Cost","sensitivity":-2.997458503628536e-9,"source":"Calculated Value","unit":"$","value":2045699.6166248296},{"name":"Layup Rate","sensitivity":0.7863506943736758,"source":"From Assumption","unit":"minute/pound","value":3},{"name":"Clean Tool Std. Dev.","sensitivity":0.0024669242340581267,"source":"From Assumption","unit":"minute","value":30},{"name":"Infuse and Cure Cell Workstations","sensitivity":-3.795574965437254e-14,"source":"Calculated Value","unit":"count","value":0.8626799057702119},{"name":"AFP Cell Time Sensitivity","sensitivity":0.7863506943736761,"source":"From Assumption","unit":"","value":1},{"name":"Infuse and Cure Subtotal Cell Cost","sensitivity":-8.917484806136855e-11,"source":"Calculated Value","unit":"$","value":215669.97647273724}]}
'''

# %%
inputdict = json.loads(inputjson)

# %%
inputdict.keys()
# Out:
# dict_keys(['sensitivities', 'processResults', 'prevCostComponents', 'manufacturing', 'modules', 'probabilities', 'options', 'design', 'costComponents', 'type', 'allVariables', 'cellResults', 'partName', 'ui'])

# %%
I = createModelFromDict(inputdict=inputdict)
# Out:
# INFO:root:attribute not found in while parsing JSON to object: designModule...skipping
# INFO:root:attribute not found in while parsing JSON to object: plyBook...skipping
# INFO:root:attribute not found in while parsing JSON to object: sign...skipping
# INFO:root:attribute not found in while parsing JSON to object: sign...skipping
# INFO:root:attribute not found in while parsing JSON to object: sign...skipping
# INFO:root:attribute not found in while parsing JSON to object: math...skipping
# INFO:root:attribute not found in while parsing JSON to object: sign...skipping
# INFO:root:attribute not found in while parsing JSON to object: math...skipping
# INFO:root:attribute not found in while parsing JSON to object: sign...skipping
# INFO:root:attribute not found in while parsing JSON to object: sign...skipping
# INFO:root:attribute not found in while parsing JSON to object: sign...skipping
# INFO:root:attribute not found in while parsing JSON to object: math...skipping
# ...

# %%
I.generate_gpx()
# Out:
# INFO:root:translating the menufactuing module to gpx models for cell based system
# DEBUG:root:Constraint interpreter|building single constraint: {'name': 'Layup Time', 'sign': '>=', 'value': ['Part Mass', '*', 'Layup Rate'], 'unit': 'min', 'math': True}
# DEBUG:root:Constraint parsing|Constraint: ['Part Mass', '*', 'Layup Rate']
# DEBUG:root:Constraint parsing|Monomial: ['Part Mass', '*', 'Layup Rate']
# DEBUG:root:Constraint parsing|Multiplication: ['Part Mass']
# DEBUG:root:Constraint parsing|Power: [['Part Mass']]
# DEBUG:root:Constraint parsing|Multiplication: ['Layup Rate']
# DEBUG:root:Constraint parsing|Power: [['Layup Rate']]
# DEBUG:root:Constraint interpreter|building single constraint: {'name': 'Layup Std. Dev.', 'sign': '>=', 'value': ['cv', '*', 'Layup Time'], 'unit': 'min', 'math': True}
# DEBUG:root:Constraint parsing|Constraint: ['cv', '*', 'Layup Time']
# DEBUG:root:Constraint parsing|Monomial: ['cv', '*', 'Layup Time']
# ...

# %%
I.gpx_model
# Out:
# <gpkit.Model object containing 30 top-level constraint(s) and 97 variable(s)>

# %%
I.solve()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-109d7076eae7> in <module>
# ----> 1 I.solve()
#
# ~/aa-refactor/copernicus-engine/interactive.py in solve(self)
#     136         'Solve the model'
#     137         # self.solution =
# --> 138         self.gpx_solution = self.gpx_model.solve()
#     139
#     140     def generate_gpx(self):
#
# ~/aa-refactor/aa-venv/py3-dev/venv/lib/python3.5/site-packages/gpkit/constraints/prog_factories.py in solvefn(self, solver, verbosity, skipsweepfailures, **kwargs)
#     121                       solver, verbosity, **kwargs)
#     122         else:
# --> 123             self.program, progsolve = genfunction(self)
#     124             result = progsolve(solver, verbosity, **kwargs)
#     125             solution.append(result)
#
# ...
