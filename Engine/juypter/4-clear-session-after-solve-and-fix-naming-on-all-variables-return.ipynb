# %%
from gpkit import Variable, Model
# Out:
# ​

# %%
t = Variable('t', hidden=True)

# %%
x = Variable("x", "m", integer=True)

# %%
dir(t)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pow__',
#  '__radd__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '_c',
#  '_cs',
#  '_exp',
#  '_exps',
#  '_hashvalue',
#  '_repr_latex_',
#  '_reset',
#  '_values',
#  '_varkeys',
#  '_varlocs',
#  'any_nonpositive_cs',
#  'c',
#  'cs',
#  'diff',
#  'exp',
#  'exps',
#  'hmap',
#  'key',
#  'latex',
#  'lineagestr',
#  'mono_approximation',
#  'mono_lower_bound',
#  'posy_negy',
#  'prod',
#  'str_without',
#  'sub',
#  'sum',
#  'to',
#  'units',
#  'unitstr',
#  'value',
#  'varkeys',
#  'varkeyvalues',
# ...
