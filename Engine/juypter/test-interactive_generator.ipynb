# %%
import json

# %% [markdown]
# working input

# %%
inputjson = '''
    {"partName":"FWD Spar","design":{"parameters":[],"plyBook":{"stack":[[{"value":0},{"value":0}],[{"value":0},{"value":0}]],"length":[[{"value":0}],[{"value":0}]],"width":[[{"value":0},{"value":0}]]}},"manufacturing":{"process":"Prepreg (8-276)","quantity":1000,"rate":40,"line":"cell","processChain":[],"cells":[]},"type":"custom","costComponents":[],"prevCostComponents":[],"options":[null],"sensitivities":[],"processResults":[],"cellResults":[],"probabilities":{"flowTime":{"boxPlot":[{"time":[181.7527567855617,217.32188963302474,289.76251948945406,362.2031493458834,418.2926569869242]},{}],"ci":0.95,"high":418.2926569869242,"low":181.7527567855617,"median":289.76251948945406,"nstd":1,"pdfPoints":[{"probability":0,"time":0},{"probability":5.3931083922113724e-18,"time":10.348661409362082},{"probability":9.97977639253273e-14,"time":20.697322818724164},{"probability":2.4678651332592428e-11,"time":31.045984228086247},{"probability":1.0428796588772931e-9,"time":41.39464563744833},{"probability":1.6738483829214126e-8,"time":51.74330704681041},{"probability":1.4563525912920686e-7,"time":62.091968456172495},{"probability":8.304244018706905e-7,"time":72.44062986553458},{"probability":0.000003475449896869914,"time":82.78929127489666},{"probability":0.000011484989264624805,"time":93.13795268425874},{"probability":0.00003150102438285472,"time":103.48661409362082},{"probability":0.00007430990037515521,"time":113.8352755029829},{"probability":0.0001547771399228943,"time":124.18393691234499},{"probability":0.0002903822967170552,"time":134.53259832170707},{"probability":0.0004983932034165747,"time":144.88125973106915},{"probability":0.000792231646290279,"time":155.22992114043123},{"probability":0.0011779172053180806,"time":165.5785825497933},{"probability":0.0016515075784990672,"time":175.9272439591554},{"probability":0.002198194169104227,"time":186.27590536851747},{"probability":0.0027932783416733296,"time":196.62456677787955},{"probability":0.0034048019839890563,"time":206.97322818724163},{"probability":0.003997266188911016,"time":217.3218895966037},{"probability":0.004535713204530275,"time":227.6705510059658},{"probability":0.004989472561912642,"time":238.01921241532787},{"probability":0.005335037160341504,"time":248.36787382468998},{"probability":0.005557771377826004,"time":258.71653523405206},{"probability":0.005652394849561627,"time":269.06519664341414},{"probability":0.005622383424642181,"time":279.4138580527762},{"probability":0.0054785570930775225,"time":289.7625194621383},{"probability":0.005237178964958673,"time":300.1111808715004},{"probability":0.004917880729372985,"time":310.45984228086246},{"probability":0.004541677615332289,"time":320.80850369022454},{"probability":0.004129260626600079,"time":331.1571650995866},{"probability":0.0036996738773233725,"time":341.5058265089487},{"probability":0.0032694133015673797,"time":351.8544879183108},{"probability":0.0028519273589321936,"time":362.20314932767286},{"probability":0.0024574632410907047,"time":372.55181073703494},{"probability":0.002093182544779098,"time":382.900472146397},{"probability":0.0017634652956644706,"time":393.2491335557591},{"probability":0.0014703265454282515,"time":403.5977949651212},{"probability":0.001213881484844027,"time":413.94645637448326},{"probability":0.0009928096566947382,"time":424.29511778384534},{"probability":0.0008047837942711341,"time":434.6437791932074},{"probability":0.0006468423181379707,"time":444.9924406025695},{"probability":0.0005156956440765843,"time":455.3411020119316},{"probability":0.0004079648508074661,"time":465.68976342129366},{"probability":0.0003203570163622114,"time":476.03842483065574},{"probability":0.00024978500225087135,"time":486.3870862400178},{"probability":0.0001934411096687305,"time":496.73574764937996},{"probability":0.0001488343377031317,"time":507.08440905874204}],"q1":217.32188963302474,"q3":362.2031493458834,"rangeMax":507.08440905874204,"rangeMin":0,"units":"hr"}},"modules":[{"name":"Spar Design","type":"design","design":[{"name":"Hole Count","sign":"=","unit":"count","value":100},{"name":"Part Perimeter","sign":">=","unit":"m","math":true,"value":["2","*","Part Length","+","2","*","Part Width"]}],"modelInputs":[{"name":"Part Length","key":"length // Spar Design","unit":"m"},{"name":"Part Width","key":"width // Spar Design","unit":"m"},{"name":"Total Layup Area","key":"layupArea // Spar Design","unit":"m^2"},{"name":"Total Surface Area","key":"surfaceArea // Spar Design","unit":"m^2"},{"name":"Hole Count","key":"holeCount // Spar Design","unit":"count"},{"name":"Cutout Perimeter","key":"cutoutPerimeter // Spar Design","unit":"m"},{"name":"Part Min. Curvature Radius","key":"curvature // Spar Design","unit":"m"},{"name":"Part Mass","key":"mass // Spar Design","unit":"kg"},{"name":"Material Cost","key":"cost // Spar Design","unit":"$"}]},{"name":"Prepreg (8-276)","type":"manufacturing","manufacturing":{"processTypes":[],"processChain":[{"#":"","type":"Layup","cell":1},{"#":"","type":"Cure","cell":2},{"#":"","type":"Trim & Drill","cell":3},{"#":"","type":"Inspect Part","cell":4}],"routes":[],"tools":[{"name":"Layup and Cure Mandrel","first":1,"last":3}],"cells":[{"id":"","name":"AFP Machine","workstationCapacity":1},{"id":"","name":"Autoclave","workstationCapacity":1},{"id":"","name":"CNC Trim","workstationCapacity":1},{"id":"","name":"NDI Tester","workstationCapacity":1}],"variables":[{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","layup rate"]},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"layup rate","sign":"=","unit":"min/lb","value":3},{"name":"cv","sign":"=","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Trim & Drill Time","sign":">=","unit":"min","math":true,"value":["drill holes","+","trim part"]},{"name":"drill holes","sign":">=","math":true,"value":["Hole Count","*","hole rate"]},{"name":"hole rate","sign":"=","unit":"min/count","value":1},{"name":"trim part","sign":">=","math":true,"value":["Part Perimeter","*","trim rate"]},{"name":"trim rate","sign":"=","unit":"sec/in","value":5},{"name":"Trim & Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim & Drill Time"]},{"name":"Inspect Part Time","sign":">=","unit":"min","math":true,"value":["Total Surface Area","*","Inspection Rate"]},{"name":"Inspect Part Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Inspect Part Time"]},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000},{"name":"CNC Trim Cell Cost","sign":"=","unit":"$","value":500000},{"name":"NDI Tester Cell Cost","sign":"=","unit":"$","value":1000000},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":5000000},{"name":"trim part","sign":"=","unit":"min"}]},"modelInputs":[{"name":"Cure Time","key":"Cure Time // Prepreg (8-276)","unit":"min"},{"name":"AFP Machine Cell Cost","key":"AFP Machine Cell Cost // Prepreg (8-276)","unit":"$"},{"name":"Autoclave Cell Cost","key":"Autoclave Cell Cost // Prepreg (8-276)","unit":"$"},{"name":"CNC Trim Cell Cost","key":"CNC Trim Cell Cost // Prepreg (8-276)","unit":"$"},{"name":"NDI Tester Cell Cost","key":"NDI Tester Cell Cost // Prepreg (8-276)","unit":"$"},{"name":"AFP Machine Head Count","key":"AFP Machine Head Count // Prepreg (8-276)","unit":"count"},{"name":"Autoclave Head Count","key":"Autoclave Head Count // Prepreg (8-276)","unit":"count"},{"name":"CNC Trim Head Count","key":"CNC Trim Head Count // Prepreg (8-276)","unit":"count"},{"name":"NDI Tester Head Count","key":"NDI Tester Head Count // Prepreg (8-276)","unit":"count"},{"name":"Layup and Cure Mandrel Tool Cost","key":"Layup and Cure Mandrel Tool Cost // Prepreg (8-276)","unit":"$"},{"name":"layup rate","key":"layup rate // Prepreg (8-276)","unit":"min/lb"},{"name":"cv","key":"cv // Prepreg (8-276)","unit":""},{"name":"hole rate","key":"hole rate // Prepreg (8-276)","unit":"min/count"},{"name":"trim rate","key":"trim rate // Prepreg (8-276)","unit":"sec/in"},{"name":"Inspection Rate","key":"Inspection Rate // Prepreg (8-276)","unit":"min/in^2"},{"name":"trim part","unit":"min"},{"name":"drill holes","unit":"min"}]}],"ui":{"editProductionDetails":false,"showModal":false,"loading":false,"numsolves":1,"developerView":true},"designModule":"Spar Design"}
'''

# %%
inputjson = '''
    {"partName":"Part Name","design":{"parameters":[],"plyBook":{"stack":[[{"value":0},{"value":0}],[{"value":0},{"value":0}]],"length":[[{"value":0}],[{"value":0}]],"width":[[{"value":0},{"value":0}]]},"designModule":"Spar Design"},"manufacturing":{"process":"Prepreg (8-276)","quantity":1000,"rate":40,"line":"cell","processChain":[],"cells":[]},"type":"custom","costComponents":[],"prevCostComponents":[],"options":[],"sensitivities":[],"processResults":[],"cellResults":[],"probabilities":{},"modules":[{"name":"Spar Design","type":"design","design":[{"name":"Part Mass","sign":"=","unit":"kg","value":250}],"modelInputs":[{"name":"Part Perimeter","key":"perimeter // Spar Design","unit":"m"},{"name":"Part Length","key":"length // Spar Design","unit":"m"},{"name":"Part Width","key":"width // Spar Design","unit":"m"},{"name":"Part Thickness","key":"thickness // Spar Design","unit":"m"},{"name":"Total Surface Area","key":"surfaceArea // Spar Design","unit":"m^2"},{"name":"Layup Area / Layer","key":"layupArea // Spar Design","unit":"m^2"},{"name":"Hole Count","key":"holeCount // Spar Design","unit":"count"},{"name":"Cutout Perimeter","key":"cutoutPerimeter // Spar Design","unit":"m"},{"name":"Part Min. Curvature Radius","key":"curvature // Spar Design","unit":"m"},{"name":"Part Mass","sign":"=","unit":"kg","value":250}]},{"name":"Prepreg (8-276)","type":"manufacturing","manufacturing":{"processTypes":[],"processChain":[{"#":"","type":"Layup","cell":1},{"#":"","type":"Cure","cell":2},{"#":"","type":"Trim and Drill","cell":3}],"routes":[],"tools":[{"name":"Layup and Cure Mandrel","first":1,"last":3}],"cells":[{"id":"","name":"AFP Machine","workstationCapacity":1},{"id":"","name":"Autoclave","workstationCapacity":1},{"id":"","name":"CNC Trim Machine","workstationCapacity":1}],"variables":[{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"]},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$"}]},"modelInputs":[{"name":"AFP Machine Head Count","key":"AFP Machine Head Count // Prepreg (8-276)","unit":"count"},{"name":"Autoclave Head Count","key":"Autoclave Head Count // Prepreg (8-276)","unit":"count"},{"name":"CNC Trim Machine Head Count","key":"CNC Trim Machine Head Count // Prepreg (8-276)","unit":"count"},{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"]},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$"}]}],"ui":{"editProductionDetails":false,"showModal":false,"loading":false,"numsolves":1,"developerView":false}}
'''

# %%
# single recurring cost
inputjson = '''
    {"partName":"Part Name","design":{"parameters":[],"plyBook":{"stack":[[{"value":0},{"value":0}],[{"value":0},{"value":0}]],"length":[[{"value":0}],[{"value":0}]],"width":[[{"value":0},{"value":0}]]},"designModule":"Spar Design"},"manufacturing":{"process":"Prepreg (8-276)","quantity":1000,"rate":40,"line":"cell","processChain":[],"cells":[]},"type":"custom","costComponents":[],"prevCostComponents":[],"options":[],"sensitivities":[],"processResults":[],"cellResults":[],"probabilities":{},"modules":[{"name":"Spar Design","type":"design","design":[{"name":"Part Mass","sign":"=","unit":"kg","value":250}],"modelInputs":[{"name":"Part Perimeter","key":"perimeter // Spar Design","unit":"m"},{"name":"Part Length","key":"length // Spar Design","unit":"m"},{"name":"Part Width","key":"width // Spar Design","unit":"m"},{"name":"Part Thickness","key":"thickness // Spar Design","unit":"m"},{"name":"Total Surface Area","key":"surfaceArea // Spar Design","unit":"m^2"},{"name":"Layup Area / Layer","key":"layupArea // Spar Design","unit":"m^2"},{"name":"Hole Count","key":"holeCount // Spar Design","unit":"count"},{"name":"Cutout Perimeter","key":"cutoutPerimeter // Spar Design","unit":"m"},{"name":"Part Min. Curvature Radius","key":"curvature // Spar Design","unit":"m"},{"name":"Part Mass","sign":"=","unit":"kg","value":250}]},{"name":"Prepreg (8-276)","type":"manufacturing","manufacturing":{"processTypes":[],"processChain":[{"#":"","type":"Layup","cell":1},{"#":"","type":"Cure","cell":2},{"#":"","type":"Trim and Drill","cell":3}],"routes":[],"tools":[{"name":"Layup and Cure Mandrel","first":1,"last":3}],"cells":[{"id":"","name":"AFP Machine","workstationCapacity":1},{"id":"","name":"Autoclave","workstationCapacity":1},{"id":"","name":"CNC Trim Machine","workstationCapacity":1}],"variables":[{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"]},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$"},{"name":"AFP Machine Head Count","sign":"=","unit":"count","value":1},{"name":"Slit Tape Material","sign":">=","unit":"$","math":true,"value":["Part Mass","*","Material Price"]},{"name":"Material Price","sign":"=","unit":"$/lb","value":80}],"costs":[{"name":"Slit Tape Material","type":"Recurring"}]},"modelInputs":[{"name":"Autoclave Head Count","key":"Autoclave Head Count // Prepreg (8-276)","unit":"count"},{"name":"CNC Trim Machine Head Count","key":"CNC Trim Machine Head Count // Prepreg (8-276)","unit":"count"},{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"]},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$"},{"name":"AFP Machine Head Count","sign":"=","unit":"count","value":1},{"name":"Slit Tape Material","sign":">=","unit":"$","math":true,"value":["Part Mass","*","Material Price"]},{"name":"Material Price","sign":"=","unit":"$/lb","value":80}]}],"ui":{"editProductionDetails":false,"showModal":false,"loading":false,"numsolves":0,"developerView":true}}
'''

# %%
# multiple recurring costs
inputdict = '''
    {"partName":"Part Name","design":{"parameters":[],"plyBook":{"stack":[[{"value":0},{"value":0}],[{"value":0},{"value":0}]],"length":[[{"value":0}],[{"value":0}]],"width":[[{"value":0},{"value":0}]]},"designModule":"Spar Design"},"manufacturing":{"process":"Prepreg (8-276)","quantity":1000,"rate":40,"line":"cell","processChain":[],"cells":[]},"type":"custom","costComponents":[],"prevCostComponents":[],"options":[],"sensitivities":[],"processResults":[],"cellResults":[],"probabilities":{},"modules":[{"name":"Spar Design","type":"design","design":[{"name":"Part Mass","sign":"=","unit":"kg","value":250}],"modelInputs":[{"name":"Part Perimeter","key":"perimeter // Spar Design","unit":"m"},{"name":"Part Length","key":"length // Spar Design","unit":"m"},{"name":"Part Width","key":"width // Spar Design","unit":"m"},{"name":"Part Thickness","key":"thickness // Spar Design","unit":"m"},{"name":"Total Surface Area","key":"surfaceArea // Spar Design","unit":"m^2"},{"name":"Layup Area / Layer","key":"layupArea // Spar Design","unit":"m^2"},{"name":"Hole Count","key":"holeCount // Spar Design","unit":"count"},{"name":"Cutout Perimeter","key":"cutoutPerimeter // Spar Design","unit":"m"},{"name":"Part Min. Curvature Radius","key":"curvature // Spar Design","unit":"m"},{"name":"Part Mass","sign":"=","unit":"kg","value":250}]},{"name":"Prepreg (8-276)","type":"manufacturing","manufacturing":{"processTypes":[],"processChain":[{"#":"","type":"Layup","cell":1},{"#":"","type":"Cure","cell":2},{"#":"","type":"Trim and Drill","cell":3}],"routes":[],"tools":[{"name":"Layup and Cure Mandrel","first":1,"last":3}],"cells":[{"id":"","name":"AFP Machine","workstationCapacity":1},{"id":"","name":"Autoclave","workstationCapacity":1},{"id":"","name":"CNC Trim Machine","workstationCapacity":1}],"variables":[{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"]},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$"},{"name":"AFP Machine Head Count","sign":"=","unit":"count","value":1},{"name":"Slit Tape Material","sign":">=","unit":"$","math":true,"value":["Part Mass","*","Material Price"]},{"name":"Material Price","sign":"=","unit":"$/lb","value":80},{"name":"IWWF Fabric","sign":"=","unit":"$","value":5000}],"costs":[{"name":"Slit Tape Material","type":"Recurring"},{"name":"IWWF Fabric","type":"Recurring"}]},"modelInputs":[{"name":"Autoclave Head Count","key":"Autoclave Head Count // Prepreg (8-276)","unit":"count"},{"name":"CNC Trim Machine Head Count","key":"CNC Trim Machine Head Count // Prepreg (8-276)","unit":"count"},{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"]},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$"},{"name":"AFP Machine Head Count","sign":"=","unit":"count","value":1},{"name":"Slit Tape Material","sign":">=","unit":"$","math":true,"value":["Part Mass","*","Material Price"]},{"name":"Material Price","sign":"=","unit":"$/lb","value":80},{"name":"IWWF Fabric","sign":"=","unit":"$","value":5000}]}],"ui":{"editProductionDetails":false,"showModal":false,"loading":false,"numsolves":0,"developerView":true}}
'''

# %%
inputdict = json.loads(inputjson)

# %%
from interactive_generators import createModelFromDict

# %%
I = createModelFromDict(inputdict)
# Out:
# design_dict:  [{'name': 'Part Mass', 'sign': '=', 'unit': 'kg', 'value': 250}]

# %%
for var in I.active_modules['manufacturing'].variables.values():
    var.infoLabels['model'] = 'manufacturing'

# %%
I.active_modules.keys()
# Out:
# dict_keys(['design', 'manufacturing'])

# %%
for key, module in I.active_modules.items():
    print(key)
# Out:
# design
# manufacturing

# %%
I.active_modules

# %% [markdown]
# #### ERROR: not generating recurring costs

# %% [markdown]
# #### ERROR: fails to generate substitutions

# %% [markdown]
# passing wrong units

# %%
I.generate_gpx()
# Out:
# INFO:root:translating the menufactuing module to gpx models for cell based system
# DEBUG:root:Constraint interpreter|building single constraint: {'sign': '>=', 'value': ['Part Mass', '*', 'Layup Rate'], 'unit': 'min', 'name': 'Layup Time', 'math': True}
# DEBUG:root:Constraint parsing|Constraint: ['Part Mass', '*', 'Layup Rate']
# DEBUG:root:Constraint parsing|Monomial: ['Part Mass', '*', 'Layup Rate']
# DEBUG:root:Constraint parsing|Multiplication: ['Part Mass']
# DEBUG:root:Constraint parsing|Power: [['Part Mass']]
# DEBUG:root:Constraint parsing|Multiplication: ['Layup Rate']
# DEBUG:root:Constraint parsing|Power: [['Layup Rate']]
# DEBUG:root:Constraint interpreter|building single constraint: {'sign': '>=', 'value': ['cv', '*', 'Layup Time'], 'unit': 'min', 'name': 'Layup Std. Dev.', 'math': True}
# DEBUG:root:Constraint parsing|Constraint: ['cv', '*', 'Layup Time']
# DEBUG:root:Constraint parsing|Monomial: ['cv', '*', 'Layup Time']
# ...

# %%
I.gpx_model
# Out:
# <gpkit.Model object containing 23 top-level constraint(s) and 84 variable(s)>

# %%
I.solve()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-109d7076eae7> in <module>
# ----> 1 I.solve()
#
# ~/aa-refactor/copernicus-engine/interactive.py in solve(self)
#     136         'Solve the model'
#     137         # self.solution =
# --> 138         self.gpx_solution = self.gpx_model.solve()
#     139
#     140     def generate_gpx(self):
#
# ~/aa-refactor/aa-venv/py3-dev/venv/lib/python3.5/site-packages/gpkit/constraints/prog_factories.py in solvefn(self, solver, verbosity, skipsweepfailures, **kwargs)
#     121                       solver, verbosity, **kwargs)
#     122         else:
# --> 123             self.program, progsolve = genfunction(self)
#     124             result = progsolve(solver, verbosity, **kwargs)
#     125             solution.append(result)
#
# ...

# %% [markdown]
# ### Variable Costs

# %%
mfgmodule = I.active_modules['manufacturing']

# %%
mfgmodule.gpxObject['varCosts']

# %%
mfgmodule.gpxObject['invHolding']

# %% [markdown]
# ## Solution returns

# %% [markdown]
# ### All variables

# %%
I.gpx_solution.keys()

# %%
I.gpx_solution['sensitivities']['variables']

# %%
I.active_modules['manufacturing'].gpxObject['cells']

# %%
I.active_modules['manufacturing'].processChain

# %%
I.create_results()

# %% [markdown]
# #### Return solutions

# %%
I.solutions

# %%
import json

# %%
for name, val in I.solutions.items():
    print(name)
    try:
        _ = json.dumps(val)
    except:
        print('issue parsing')

# %%
all_gpx_vars = {**I.active_modules['design'].gpx_variables,
                **I.active_modules['manufacturing'].gpx_variables}

# %%
sol = I.gpx_solution

# %%
samplecell = I.active_modules['manufacturing'].gpxObject['cells']['Autoclave']

# %%
samplecell.chicv

# %%
sol['variables'][samplecell.m]

# %%
print(sol.table())

# %%
I.solutions['allVariables']

# %%
I.active_modules['manufacturing'].cells

# %%
I.active_modules['manufacturing'].gpxObject['cells']

# %%
I.active_modules['manufacturing'].gpx_variables

# %%
I.collected_variables

# %%
I.active_modules['manufacturing'].costs

# %%
inputdict['modules'][1]['manufacturing']
