# %%
from gpx.primitives import Process

# %%
from gpkit import parse_variables

# %%
from gpx.manufacturing import QNACell

# %%
QNACell()
# Out:
# <gpkit.QNACell object containing 7 top-level constraint(s) and 16 variable(s)>

# %%
cells = [QNACell() for i in range(4)]

# %%
from gpx.manufacturing import FabLine

# %%
FabLine(cells)
# Out:
# <gpkit.FabLine object containing 1 top-level constraint(s) and 19 variable(s)>

# %%
from gpx.non_recurring_costs import ConwipToolingCost

# %%
ConwipToolingCost(cells, 1, 3)
# Out:
# <gpkit.ConwipToolingCost object containing 3 top-level constraint(s) and 11 variable(s)>
