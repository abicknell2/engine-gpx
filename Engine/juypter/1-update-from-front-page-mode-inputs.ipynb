# %%
import json

# %%
# model3
inputjson = '''
    {"partName":"Part Name","design":{"parameters":[],"plyBook":{"stack":[[{"value":0},{"value":0}],[{"value":0},{"value":0}]],"length":[[{"value":0}],[{"value":0}]],"width":[[{"value":0},{"value":0}]]},"designModule":"Spar Design"},"manufacturing":{"process":"Prepreg (8-276)","quantity":1000,"rate":40,"line":"cell","processChain":[],"cells":[]},"type":"custom","costComponents":[{"name":"AFP Machine","value":18263924.357872818},{"name":"Autoclave","value":10791834.456561126},{"name":"CNC Trim Machine","value":1246131.6469915633},{"name":"Layup and Cure Mandrel","value":7355715.995274291},{"name":"Total","value":37657606.456699796}],"prevCostComponents":[],"options":[],"sensitivities":[{"name":"Autoclave Head Count","value":0.025401200816918042},{"name":"IWWF Fabric","value":0.052919167210734454},{"name":"Autoclave Cell Cost","value":0.11421897953271092},{"name":"CNC Trim Machine Cell Cost","value":0.013188829459137151},{"name":"Layup Rate","value":0.27382548699612996},{"name":"CNC Trim Machine Head Count","value":0.012700601198631948},{"name":"Trim and Drill Time","value":0.036564630524492076},{"name":"Part Mass","value":0.7404926597065038},{"name":"cv","value":0.04080042745834276},{"name":"AFP Machine Cell Cost","value":0.19330233580189182},{"name":"Material Price","value":0.4666671727103739},{"name":"Cure Time","value":0.15029537973141127},{"name":"Layup and Cure Mandrel Tool Cost","value":0.07785166491430566},{"name":"AFP Machine Head Count","value":0.04375004838927245}],"processResults":[{"processTime":1653.4669692099103,"stdev":413.3668314372821,"type":"Layup"},{"processTime":480,"stdev":120.00012661313102,"type":"Cure"},{"processTime":480,"stdev":120.00006450947153,"type":"Trim and Drill"}],"cellResults":[{"cellTimeSensitivity":0.2738254869961298,"cellVariationSensitivity":0.01807933125980116,"laborCost":4133.6674517107085,"name":"AFP Machine","numWorkstations":3.652784865755352,"queueingTime":468.39590419683975,"queueingTimeUnit":"minute","utilization":0.9430401704205548,"wip":4.420547130687609},{"cellTimeSensitivity":0.15029537973141127,"cellVariationSensitivity":0.011814798377633974,"laborCost":2400.0000214523443,"name":"Autoclave","numWorkstations":1.0791834384141834,"queueingTime":351.0686785565685,"queueingTimeUnit":"minute","utilization":0.9266265338757399,"wip":1.7313929946128412},{"cellTimeSensitivity":0.036564630524492076,"cellVariationSensitivity":0.01090629783383403,"laborCost":1200.0000899496586,"name":"CNC Trim Machine","numWorkstations":1.2461313971379009,"queueingTime":97.81247301093808,"queueingTimeUnit":"minute","utilization":0.8024838971203052,"wip":1.2037756523980483}],"probabilities":{},"modules":[{"name":"Spar Design","type":"design","design":[{"name":"Part Mass","sign":"=","unit":"kg","value":250}],"modelInputs":[{"name":"Part Perimeter","key":"perimeter // Spar Design","unit":"m"},{"name":"Part Length","key":"length // Spar Design","unit":"m"},{"name":"Part Width","key":"width // Spar Design","unit":"m"},{"name":"Part Thickness","key":"thickness // Spar Design","unit":"m"},{"name":"Total Surface Area","key":"surfaceArea // Spar Design","unit":"m^2"},{"name":"Layup Area / Layer","key":"layupArea // Spar Design","unit":"m^2"},{"name":"Hole Count","key":"holeCount // Spar Design","unit":"count"},{"name":"Cutout Perimeter","key":"cutoutPerimeter // Spar Design","unit":"m"},{"name":"Part Min. Curvature Radius","key":"curvature // Spar Design","unit":"m"},{"name":"Part Mass","sign":"=","unit":"kg","value":250}]},{"name":"Prepreg (8-276)","type":"manufacturing","manufacturing":{"processTypes":[],"processChain":[{"#":"","type":"Layup","cell":1},{"#":"","type":"Cure","cell":2},{"#":"","type":"Trim and Drill","cell":3}],"routes":[],"tools":[{"name":"Layup and Cure Mandrel","first":1,"last":3}],"cells":[{"id":"","name":"AFP Machine","workstationCapacity":1},{"id":"","name":"Autoclave","workstationCapacity":1},{"id":"","name":"CNC Trim Machine","workstationCapacity":1}],"variables":[{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"]},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$"},{"name":"AFP Machine Head Count","sign":"=","unit":"count","value":1},{"name":"Slit Tape Material","sign":">=","unit":"$","math":true,"value":["Part Mass","*","Material Price"]},{"name":"Material Price","sign":"=","unit":"$/lb","value":80},{"name":"IWWF Fabric","sign":"=","unit":"$","value":5000},{"name":"Autoclave Head Count","sign":"=","unit":"count","value":2},{"name":"CNC Trim Machine Head Count","sign":"=","unit":"count","value":1}],"costs":[{"name":"Slit Tape Material","type":"Recurring"},{"name":"IWWF Fabric","type":"Recurring"}]},"modelInputs":[{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"]},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$"},{"name":"AFP Machine Head Count","sign":"=","unit":"count","value":1},{"name":"Slit Tape Material","sign":">=","unit":"$","math":true,"value":["Part Mass","*","Material Price"]},{"name":"Material Price","sign":"=","unit":"$/lb","value":80},{"name":"IWWF Fabric","sign":"=","unit":"$","value":5000},{"name":"Autoclave Head Count","sign":"=","unit":"count","value":2},{"name":"CNC Trim Machine Head Count","sign":"=","unit":"count","value":1}]}],"ui":{"editProductionDetails":false,"showModal":false,"loading":false,"numsolves":1,"developerView":false},"allVariables":[{"name":"Layup and Cure Mandrel Subtotal Tool Cost","sensitivity":3.169029622052122e-9,"source":"Calculated Value","unit":"$","value":7355715.995274291},{"name":"Total Recurring Cost","sensitivity":-1.7301083898857428e-9,"source":"Calculated Value","unit":"$","value":56889.61756668462},{"name":"IWWF Fabric","sensitivity":0.052919167210734454,"source":"From Assumption","unit":"$","value":5000},{"name":"Autoclave Cell Cost","sensitivity":0.11421897953271092,"source":"From Assumption","unit":"$","value":10000000},{"name":"Autoclave Cell Queueing Time","sensitivity":3.8004385749523806e-9,"source":"Calculated Value","unit":"minute","value":351.0686785565685},{"name":"Autoclave Cell Workstations","sensitivity":-4.308803314145848e-12,"source":"Calculated Value","unit":"count","value":1.0791834384141834},{"name":"Layup Rate","sensitivity":0.27382548699612996,"source":"From Assumption","unit":"minute/pound","value":3},{"name":"CNC Trim Machine Head Count","sensitivity":0.012700601198631948,"source":"From Assumption","unit":"count","value":1},{"name":"CNC Trim Machine Cell Workstations","sensitivity":-4.308799844698896e-12,"source":"Calculated Value","unit":"count","value":1.2461313971379009},{"name":"Autoclave Cell Variation Sensitivity","sensitivity":0.011814798377633974,"source":"From Assumption","unit":"","value":1},{"name":"CNC Trim Machine Cell Queueing Time","sensitivity":7.094770521510335e-9,"source":"Calculated Value","unit":"minute","value":97.81247301093808},{"name":"AFP Machine Cell Queueing Time","sensitivity":8.933537163496874e-9,"source":"Calculated Value","unit":"minute","value":468.39590419683975},{"name":"Part Mass","sensitivity":0.7404926597065038,"source":"From Assumption","unit":"kilogram","value":250},{"name":"AFP Machine Cell Cost","sensitivity":0.19330233580189182,"source":"From Assumption","unit":"$","value":5000000},{"name":"Trim and Drill Std. Dev.","sensitivity":1.734723475976807e-18,"source":"Calculated Value","unit":"minute","value":120.00006450947153},{"name":"Total Unit Cost","sensitivity":4.30910862547762e-12,"source":"Calculated Value","unit":"$","value":94547.2206608185},{"name":"CNC Trim Machine Cell Time Sensitivity","sensitivity":0.036564630524492076,"source":"From Assumption","unit":"","value":1},{"name":"cv","sensitivity":0.04080042745834276,"source":"From Assumption","unit":"","value":0.25},{"name":"Autoclave Cell Time Sensitivity","sensitivity":0.15029537973141127,"source":"From Assumption","unit":"","value":1},{"name":"CNC Trim Machine Subtotal Cell Cost","sensitivity":1.951655111305517e-8,"source":"Calculated Value","unit":"$","value":1246131.6469915633},{"name":"AFP Machine Cell Time Sensitivity","sensitivity":0.2738254869961298,"source":"From Assumption","unit":"","value":1},{"name":"CNC Trim Machine Cell Cost","sensitivity":0.013188829459137151,"source":"From Assumption","unit":"$","value":1000000},{"name":"AFP Machine Cell Variation Sensitivity","sensitivity":0.01807933125980116,"source":"From Assumption","unit":"","value":1},{"name":"AFP Machine Head Count","sensitivity":0.04375004838927245,"source":"From Assumption","unit":"count","value":1},{"name":"Autoclave Subtotal Cell Cost","sensitivity":-8.237154736079333e-9,"source":"Calculated Value","unit":"$","value":10791834.456561126},{"name":"AFP Machine Cell Workstations","sensitivity":-4.308720047419001e-12,"source":"Calculated Value","unit":"count","value":3.652784865755352},{"name":"Cure Std. Dev.","sensitivity":0,"source":"Calculated Value","unit":"minute","value":120.00012661313102},{"name":"Trim and Drill Time","sensitivity":0.036564630524492076,"source":"From Assumption","unit":"minute","value":480},{"name":"Autoclave Head Count","sensitivity":0.025401200816918042,"source":"From Assumption","unit":"count","value":2},{"name":"Total Non-Recurring Cost","sensitivity":1.7257990592156602e-9,"source":"Calculated Value","unit":"$","value":37657604.110543564},{"name":"Material Price","sensitivity":0.4666671727103739,"source":"From Assumption","unit":"$","value":80},{"name":"Slit Tape Material","sensitivity":-3.814781823763269e-12,"source":"Calculated Value","unit":"$","value":44092.45244243921},{"name":"Layup Std. Dev.","sensitivity":0,"source":"Calculated Value","unit":"minute","value":413.3668314372821},{"name":"AFP Machine Subtotal Cell Cost","sensitivity":-1.4461352365602309e-8,"source":"Calculated Value","unit":"$","value":18263924.357872818},{"name":"Cure Time","sensitivity":0.15029537973141127,"source":"From Assumption","unit":"minute","value":480},{"name":"Layup and Cure Mandrel Tool Cost","sensitivity":0.07785166491430566,"source":"From Assumption","unit":"$","value":1000000},{"name":"CNC Trim Machine Cell Variation Sensitivity","sensitivity":0.01090629783383403,"source":"From Assumption","unit":"","value":1},{"name":"Layup Time","sensitivity":-1.4224732503009818e-16,"source":"Calculated Value","unit":"minute","value":1653.4669692099103}]}
'''

# %%
#model4 with uncertainty on constrained variables
inputjson = '''
    {"partName":"Part Name","design":{"parameters":[],"plyBook":{"stack":[[{"value":0},{"value":0}],[{"value":0},{"value":0}]],"length":[[{"value":0}],[{"value":0}]],"width":[[{"value":0},{"value":0}]]},"designModule":"Spar Design"},"manufacturing":{"process":"Prepreg (8-276)","quantity":1000,"rate":40,"line":"cell","processChain":[],"cells":[]},"type":"bestworst","modules":[{"name":"Spar Design","type":"design","design":[{"name":"Part Mass","sign":"=","unit":"kg","value":250}],"modelInputs":[{"name":"Part Perimeter","key":"perimeter // Spar Design","unit":"m"},{"name":"Part Length","key":"length // Spar Design","unit":"m"},{"name":"Part Width","key":"width // Spar Design","unit":"m"},{"name":"Part Thickness","key":"thickness // Spar Design","unit":"m"},{"name":"Total Surface Area","key":"surfaceArea // Spar Design","unit":"m^2"},{"name":"Layup Area / Layer","key":"layupArea // Spar Design","unit":"m^2"},{"name":"Hole Count","key":"holeCount // Spar Design","unit":"count"},{"name":"Cutout Perimeter","key":"cutoutPerimeter // Spar Design","unit":"m"},{"name":"Part Min. Curvature Radius","key":"curvature // Spar Design","unit":"m"},{"name":"Part Mass","sign":"=","unit":"kg","value":250}]},{"name":"Prepreg (8-276)","type":"manufacturing","manufacturing":{"processTypes":[],"processChain":[{"#":"","type":"Layup","cell":1},{"#":"","type":"Cure","cell":2},{"#":"","type":"Trim and Drill","cell":3}],"routes":[],"tools":[{"name":"Layup and Cure Mandrel","first":1,"last":3}],"cells":[{"id":"","name":"AFP Machine","workstationCapacity":1},{"id":"","name":"Autoclave","workstationCapacity":1},{"id":"","name":"CNC Trim Machine","workstationCapacity":1}],"variables":[{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"]},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$"},{"name":"AFP Machine Head Count","sign":"=","unit":"count","value":1},{"name":"Slit Tape Material","sign":">=","unit":"$","math":true,"value":["Part Mass","*","Material Price"]},{"name":"Material Price","sign":"=","unit":"$/lb","value":80},{"name":"IWWF Fabric","sign":"=","unit":"$","value":5000},{"name":"Autoclave Head Count","sign":"=","unit":"count","value":2},{"name":"CNC Trim Machine Head Count","sign":"=","unit":"count","value":1}],"costs":[{"name":"Slit Tape Material","type":"Recurring"},{"name":"IWWF Fabric","type":"Recurring"}]},"modelInputs":[{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"]},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$"},{"name":"AFP Machine Head Count","sign":"=","unit":"count","value":1},{"name":"Slit Tape Material","sign":">=","unit":"$","math":true,"value":["Part Mass","*","Material Price"]},{"name":"Material Price","sign":"=","unit":"$/lb","value":80},{"name":"IWWF Fabric","sign":"=","unit":"$","value":5000},{"name":"Autoclave Head Count","sign":"=","unit":"count","value":2},{"name":"CNC Trim Machine Head Count","sign":"=","unit":"count","value":1}]}],"inputs":[{"name":"Part Perimeter","key":"perimeter // Spar Design","unit":"m","model":"Spar Design"},{"name":"Part Length","key":"length // Spar Design","unit":"m","model":"Spar Design"},{"name":"Part Width","key":"width // Spar Design","unit":"m","model":"Spar Design"},{"name":"Part Thickness","key":"thickness // Spar Design","unit":"m","model":"Spar Design"},{"name":"Total Surface Area","key":"surfaceArea // Spar Design","unit":"m^2","model":"Spar Design"},{"name":"Layup Area / Layer","key":"layupArea // Spar Design","unit":"m^2","model":"Spar Design"},{"name":"Hole Count","key":"holeCount // Spar Design","unit":"count","model":"Spar Design"},{"name":"Cutout Perimeter","key":"cutoutPerimeter // Spar Design","unit":"m","model":"Spar Design"},{"name":"Part Min. Curvature Radius","key":"curvature // Spar Design","unit":"m","model":"Spar Design"},{"name":"Part Mass","sign":"=","unit":"kg","value":250,"model":"Spar Design","likely":250},{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"],"model":"Prepreg (8-276)","isConstrained":true},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3,"model":"Prepreg (8-276)","likely":3},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"],"model":"Prepreg (8-276)","isConstrained":true,"likely":15},{"name":"cv","sign":"=","unit":"","value":0.25,"model":"Prepreg (8-276)","likely":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480,"model":"Prepreg (8-276)","likely":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"],"model":"Prepreg (8-276)","isConstrained":true},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480,"model":"Prepreg (8-276)","likely":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"],"model":"Prepreg (8-276)","isConstrained":true},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000,"model":"Prepreg (8-276)","likely":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000,"model":"Prepreg (8-276)","likely":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000,"model":"Prepreg (8-276)","likely":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$","model":"Prepreg (8-276)","likely":1000000},{"name":"AFP Machine Head Count","sign":"=","unit":"count","value":1,"model":"Prepreg (8-276)","likely":1},{"name":"Slit Tape Material","sign":">=","unit":"$","math":true,"value":["Part Mass","*","Material Price"],"model":"Prepreg (8-276)","isConstrained":true},{"name":"Material Price","sign":"=","unit":"$/lb","value":80,"model":"Prepreg (8-276)","likely":80},{"name":"IWWF Fabric","sign":"=","unit":"$","value":5000,"model":"Prepreg (8-276)","likely":5000},{"name":"Autoclave Head Count","sign":"=","unit":"count","value":2,"model":"Prepreg (8-276)","likely":2},{"name":"CNC Trim Machine Head Count","sign":"=","unit":"count","value":1,"model":"Prepreg (8-276)","likely":1}],"costComponents":[{"name":"AFP Machine","value":18263924.357872818},{"name":"Autoclave","value":10791834.456561165},{"name":"CNC Trim Machine","value":1246131.6469915633},{"name":"Layup and Cure Mandrel","value":7355715.995274291}],"prevCostComponents":[]}
'''

# %%
#model4 with layup rate changed
inputjson = '''
    {"partName":"Part Name","design":{"parameters":[],"plyBook":{"stack":[[{"value":0},{"value":0}],[{"value":0},{"value":0}]],"length":[[{"value":0}],[{"value":0}]],"width":[[{"value":0},{"value":0}]]},"designModule":"Spar Design"},"manufacturing":{"process":"Prepreg (8-276)","quantity":1000,"rate":40,"line":"cell","processChain":[],"cells":[]},"type":"bestworst","modules":[{"name":"Spar Design","type":"design","design":[{"name":"Part Mass","sign":"=","unit":"kg","value":250}],"modelInputs":[{"name":"Part Perimeter","key":"perimeter // Spar Design","unit":"m"},{"name":"Part Length","key":"length // Spar Design","unit":"m"},{"name":"Part Width","key":"width // Spar Design","unit":"m"},{"name":"Part Thickness","key":"thickness // Spar Design","unit":"m"},{"name":"Total Surface Area","key":"surfaceArea // Spar Design","unit":"m^2"},{"name":"Layup Area / Layer","key":"layupArea // Spar Design","unit":"m^2"},{"name":"Hole Count","key":"holeCount // Spar Design","unit":"count"},{"name":"Cutout Perimeter","key":"cutoutPerimeter // Spar Design","unit":"m"},{"name":"Part Min. Curvature Radius","key":"curvature // Spar Design","unit":"m"},{"name":"Part Mass","sign":"=","unit":"kg","value":250}]},{"name":"Prepreg (8-276)","type":"manufacturing","manufacturing":{"processTypes":[],"processChain":[{"#":"","type":"Layup","cell":1},{"#":"","type":"Cure","cell":2},{"#":"","type":"Trim and Drill","cell":3}],"routes":[],"tools":[{"name":"Layup and Cure Mandrel","first":1,"last":3}],"cells":[{"id":"","name":"AFP Machine","workstationCapacity":1},{"id":"","name":"Autoclave","workstationCapacity":1},{"id":"","name":"CNC Trim Machine","workstationCapacity":1}],"variables":[{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"]},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$"},{"name":"AFP Machine Head Count","sign":"=","unit":"count","value":1},{"name":"Slit Tape Material","sign":">=","unit":"$","math":true,"value":["Part Mass","*","Material Price"]},{"name":"Material Price","sign":"=","unit":"$/lb","value":80},{"name":"IWWF Fabric","sign":"=","unit":"$","value":5000},{"name":"Autoclave Head Count","sign":"=","unit":"count","value":2},{"name":"CNC Trim Machine Head Count","sign":"=","unit":"count","value":1}],"costs":[{"name":"Slit Tape Material","type":"Recurring"},{"name":"IWWF Fabric","type":"Recurring"}]},"modelInputs":[{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"]},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"]},{"name":"cv","sign":"=","unit":"","value":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"]},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"]},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$"},{"name":"AFP Machine Head Count","sign":"=","unit":"count","value":1},{"name":"Slit Tape Material","sign":">=","unit":"$","math":true,"value":["Part Mass","*","Material Price"]},{"name":"Material Price","sign":"=","unit":"$/lb","value":80},{"name":"IWWF Fabric","sign":"=","unit":"$","value":5000},{"name":"Autoclave Head Count","sign":"=","unit":"count","value":2},{"name":"CNC Trim Machine Head Count","sign":"=","unit":"count","value":1}]}],"inputs":[{"name":"Part Perimeter","key":"perimeter // Spar Design","unit":"m","model":"Spar Design"},{"name":"Part Length","key":"length // Spar Design","unit":"m","model":"Spar Design"},{"name":"Part Width","key":"width // Spar Design","unit":"m","model":"Spar Design"},{"name":"Part Thickness","key":"thickness // Spar Design","unit":"m","model":"Spar Design"},{"name":"Total Surface Area","key":"surfaceArea // Spar Design","unit":"m^2","model":"Spar Design"},{"name":"Layup Area / Layer","key":"layupArea // Spar Design","unit":"m^2","model":"Spar Design"},{"name":"Hole Count","key":"holeCount // Spar Design","unit":"count","model":"Spar Design"},{"name":"Cutout Perimeter","key":"cutoutPerimeter // Spar Design","unit":"m","model":"Spar Design"},{"name":"Part Min. Curvature Radius","key":"curvature // Spar Design","unit":"m","model":"Spar Design"},{"name":"Part Mass","sign":"=","unit":"kg","value":250,"model":"Spar Design","likely":250},{"name":"Layup Time","sign":">=","unit":"min","math":true,"value":["Part Mass","*","Layup Rate"],"model":"Prepreg (8-276)","isConstrained":true},{"name":"Layup Rate","sign":"=","unit":"min/lb","value":3,"model":"Prepreg (8-276)","likely":5},{"name":"Layup Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Layup Time"],"model":"Prepreg (8-276)","isConstrained":true,"likely":15},{"name":"cv","sign":"=","unit":"","value":0.25,"model":"Prepreg (8-276)","likely":0.25},{"name":"Cure Time","sign":"=","unit":"min","value":480,"model":"Prepreg (8-276)","likely":480},{"name":"Cure Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Cure Time"],"model":"Prepreg (8-276)","isConstrained":true},{"name":"Trim and Drill Time","sign":"=","unit":"min","value":480,"model":"Prepreg (8-276)","likely":480},{"name":"Trim and Drill Std. Dev.","sign":">=","unit":"min","math":true,"value":["cv","*","Trim and Drill Time"],"model":"Prepreg (8-276)","isConstrained":true},{"name":"Layup and Cure Mandrel Tool Cost","sign":"=","unit":"$","value":1000000,"model":"Prepreg (8-276)","likely":1000000},{"name":"AFP Machine Cell Cost","sign":"=","unit":"$","value":5000000,"model":"Prepreg (8-276)","likely":5000000},{"name":"Autoclave Cell Cost","sign":"=","unit":"$","value":10000000,"model":"Prepreg (8-276)","likely":10000000},{"name":"CNC Trim Machine Cell Cost","sign":"=","value":1000000,"unit":"$","model":"Prepreg (8-276)","likely":1000000},{"name":"AFP Machine Head Count","sign":"=","unit":"count","value":1,"model":"Prepreg (8-276)","likely":1},{"name":"Slit Tape Material","sign":">=","unit":"$","math":true,"value":["Part Mass","*","Material Price"],"model":"Prepreg (8-276)","isConstrained":true},{"name":"Material Price","sign":"=","unit":"$/lb","value":80,"model":"Prepreg (8-276)","likely":80},{"name":"IWWF Fabric","sign":"=","unit":"$","value":5000,"model":"Prepreg (8-276)","likely":5000},{"name":"Autoclave Head Count","sign":"=","unit":"count","value":2,"model":"Prepreg (8-276)","likely":2},{"name":"CNC Trim Machine Head Count","sign":"=","unit":"count","value":1,"model":"Prepreg (8-276)","likely":1}],"costComponents":[{"name":"AFP Machine","value":18263924.357872818},{"name":"Autoclave","value":10791834.456561165},{"name":"CNC Trim Machine","value":1246131.6469915633},{"name":"Layup and Cure Mandrel","value":7355715.995274291}],"prevCostComponents":[]}
'''

# %%
inputdict = json.loads(inputjson)

# %%
from interactive_generators import createModelFromDict

# %%
I = createModelFromDict(inputdict)
# Out:
# design_dict:  [{'name': 'Part Mass', 'sign': '=', 'unit': 'kg', 'value': 250}]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 I = createModelFromDict(inputdict)
#
# File /mnt/c/Development/Code/Engine/interactive_generators.py:77, in createModelFromDict(inputdict)
#      74     Interactive.is_uncertain = True
#      76 # create the modules
# ---> 77 Interactive.modules = ModelModules(
#      78     construct_from_dict=inputdict["modules"], designrequired=requires_design
#      79 )
#      81 # set active module
#      82 try:
#
# File /mnt/c/Development/Code/Engine/modules.py:43, in ModelModules.__init__(self, **kwargs)
#      41 def __init__(self, **kwargs):
#      42     self.modules = []
# ---> 43     super().__init__(**kwargs)
#
# File /mnt/c/Development/Code/Engine/objects.py:62, in CopernicusObject.__init__(self, **args)
# ...

# %%
I.module_map

# %%
I.active_modules['manufacturing'].substitutions

# %%
I.active_modules['manufacturing'].constraints

# %%
I.active_modules['manufacturing'].substitutions

# %%
inputdict['modules'][1]['manufacturing']

# %%
from modules import update_module_constraints_bestworst

# %%
mfgmodule = I.active_modules['manufacturing']

# %%
updates = inputdict['inputs']

# %%
import logging

# %%
logging.basicConfig(level=logging.DEBUG)

# %%
updates

# %% [markdown]
# this should have captured #12

# %% [markdown]
# #### TESTING: logic for finding the variables

# %%
updates[12]

# %%
var = updates[12]

# %%
vars_to_update = []

# %%
if 'isConstrained' in var and var['isConstrained']:
    if 'likely' in var and var['likely'] is not None:
        vars_to_update.append(var)
    elif 'best' in var and 'worst' in var:
        if var['best'] is not None and var['worst'] is not None:
            vars_to_update.append(var)

# %%
vars_to_update

# %%
mfgmodule.constraints

# %%
# mfgmodule._original_constraints

# %%
update_module_constraints_bestworst(mfgmodule, *updates)

# %%
mfgmodule.constraints

# %%
mfgmodule.substitutions

# %% [markdown]
# ### Not catching `null`

# %%
json.loads('{"test": null}')

# %%
import numpy as np

# %%
np.mean([1,2])
